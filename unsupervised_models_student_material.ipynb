# %% [markdown]
# <a href="https://colab.research.google.com/github/UmadeviGovindarajan/pandas_numpy/blob/main/unsupervised_models_student_material.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Session Flow**
# * **Learning Objective**
#  - Introduction
#  - Theme
#  - Primary Goals:
# * Learning Material
#   - Clustering Algorithms
#      - K-means Clustering
#      - Hierarchical Clustering
#      - Density-based Clustering
#   - Activity 1: Fill in the Blanks
#   - Dimensionality Reduction Techniques
#      - Principal Component Analysis
#       t-SNE (t-Distributed Stochastic Neighbor Embedding)
#      - UMAP (Uniform Manifold Approximation and Projection)
#   - Activity 2: True or False
#   - Recommendation System
#      - Collaborative Filtering
#         - Matrix Factorization
#   - Activity 3: Guess the Word
# * **Summary**
#  - What did you learn?
#  - Best Practices/Tips
#  - Shortcomings
# * **Enhance Your Knowledge**
#   - Additional Reference Paper
#   - Mnemonic
# * **Try it Yourself**
#   - Take Home Assignment

# %% [markdown]
# #**Learning Objective**

# %% [markdown]
# ## **Introduction**
# Unsupervised learning 🤖 is a type of machine learning where the algorithm learns patterns and relationships in the data without any labeled examples. Unlike supervised learning 📊, where the algorithm is trained on labeled data to make predictions on new, unseen data, unsupervised learning aims to identify inherent patterns and structures within the data. This makes it an essential tool 🔧 for data exploration 🌍, visualization 📈, and clustering 🤝, and can be used for a wide variety of applications in industry.
#
# ---

# %% [markdown]
# ##**Theme** 🌟🤖
#
# According to studies, approximately 35% of Amazon's revenue is generated through their recommendation system, demonstrating its effectiveness in driving sales and customer satisfaction. Similarly, Netflix estimates that around 80% of content viewed on their platform is a result of their recommendation algorithm, showcasing the immense impact of personalized recommendations on user engagement and retention.
#
# For Instance , you can  organize a closet filled with clothes of different colors and styles using Clustering Algorithms. By grouping similar items together, you can easily find the perfect outfit for any occasion. 🧥👚👖
#
# Dimensionality Reduction Techniques work like condensing a long list of favorite recipes into a concise cookbook, allowing you to quickly find and try new dishes without feeling overwhelmed. 🗒️🍳🥗
#
# Moreover, consider how a personalized Recommendation System can simplify shopping for gifts. By analyzing past purchases and preferences, it suggests thoughtful and relevant present ideas for your loved ones. 🎁💡🎉
#
# Incorporate these practical Unsupervised Learning concepts into your daily life and gain valuable insights to enhance decision-making in diverse scenarios! 🚀💡🔍
#
# ---

# %% [markdown]
# ## **Primary Goals:**
#
# Develop a comprehensive understanding of unsupervised learning algorithms and their applications in various domains.
#
# 2️⃣ Explore popular clustering algorithms like k-Means, hierarchical clustering, and DBSCAN, and understand their working principles and use cases.
#
# 3️⃣ Master dimensionality reduction techniques like Principal Component Analysis (PCA), t-SNE, and UMAP to effectively handle high-dimensional data and visualize complex datasets.
#
# 4️⃣ Learn about recommendation systems, collaborative filtering, and matrix factorization to build personalized recommendation engines for users.
#
# 5️⃣ Gain hands-on experience in implementing unsupervised algorithms using Python libraries like Scikit-Learn, and apply these techniques to real-world datasets.
#
# 🚀 By achieving these goals, you'll be equipped with the knowledge and skills to apply unsupervised learning techniques to a wide range of data analysis and problem-solving tasks, making you a proficient machine learning practitioner ready to tackle real-world challenges!

# %% [markdown]
# #**📖Learning Material📖**

# %% [markdown]
# Hey there! 👋 Let's learn about unsupervised learning - the rebel of machine learning! 😎

# %% [markdown]
# So, you know how in supervised learning, the algorithm is kind of like a student being taught by a teacher?
#
# 🧑‍🏫👩‍🏫 Well, in unsupervised learning, it's more like the algorithm is a curious little explorer, wandering around in the data trying to find patterns all on its own! 🕵️‍♀️🕵️‍♂️🔍

# %% [markdown]
# ![Unsupervised-Machin.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Unsupervised learning has a wide range of applications in various industries. Here are some examples:**

# %% [markdown]
# ![machine-learning-applications.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Anomaly detection:** 🔍 Unsupervised learning algorithms can identify unusual patterns in data that might indicate a fraud or a defect in a manufacturing process.
#
# **Customer segmentation:** 🤝 By clustering customers based on their preferences or behaviors, unsupervised learning algorithms can help businesses understand their customers better and tailor their marketing strategies accordingly.
#
# **Product recommendations:** 🛍️ Unsupervised learning can be used to recommend products to customers based on their purchase history and preferences.
#
# **Image and speech recognition:** 📷🎤 Unsupervised learning can be used to identify patterns and features in images and audio data, making it possible to recognize faces, objects, and speech.
#
# **Natural language processing:** 🗣️ Unsupervised learning can be used for tasks such as topic modeling, where the algorithm identifies the main topics present in a large corpus of text, or for language modeling, where the algorithm predicts the next word in a sentence based on the context of the previous words.
#
# **Fraud detection:** 💳 Unsupervised learning algorithms can identify unusual patterns in financial transactions that might indicate fraudulent activity.
#
# **Network intrusion detection:** 🛡️ Unsupervised learning can be used to identify unusual patterns in network traffic that might indicate an attack.
#
# **Data compression:**📉 Unsupervised learning can be used to reduce the dimensionality of large datasets, making it possible to store and process them more efficiently.
#
# **Market segmentation:** 🎯 Unsupervised learning algorithms can be used to segment markets into different groups based on variables such as demographics, behavior, and preferences. This allows businesses to tailor their products and marketing strategies to specific groups of customers, increasing the effectiveness of their marketing campaigns and improving customer satisfaction.
#
# **Recommendation systems:**💡 Unsupervised learning algorithms can be used to build recommendation systems that suggest products or services to customers based on their preferences and behavior. This is commonly used in e-commerce websites and streaming services to suggest products, movies, or TV shows that the user might be interested in.
#
# **Sensor data analysis:** 🔬 Unsupervised learning can be used to analyze sensor data from various sources such as IoT devices or industrial machinery, to detect patterns or anomalies that might indicate a fault or a failure in the system. This can help businesses prevent downtime and optimize their operations.
#
# **Quality control:** 👨‍🔬 Unsupervised learning algorithms can be used to analyze data from quality control processes in manufacturing, to identify patterns that might indicate a defect in the production process.
#
# Overall, unsupervised learning algorithms are versatile tools that can be applied to a wide range of problems and industries, helping businesses extract insights from data and optimize their operations.
#
# ---

# %% [markdown]
# ## **Clustering Algorithms**

# %% [markdown]
# 🤖 Clustering algorithms are like matchmakers for data points! 🤝 They group together similar data points based on their attributes or features. The goal is to uncover hidden patterns and structures in the data that we humans might miss.

# %% [markdown]
# ![Distribution-based-clustering.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Clustering algorithms is a type of unsupervised learning algorithm that is used to group similar data points together based on their attributes or features. The goal of clustering is to identify inherent patterns and structures within the data that might not be immediately apparent to a human observer.

# %% [markdown]
# There are several types of clustering algorithms, including:
#
# * K-means clustering
#
#
# * Hierarchical clustering
#
# * Density-based clustering

# %% [markdown]
# ### **K-means Clustering**

# %% [markdown]
# Let me tell you about K-means clustering, a cool unsupervised learning algorithm! 🤖💡

# %% [markdown]
# Basically, K-means clustering helps partition a dataset into a specific number of clusters by assigning each data point to the nearest centroid and then recalculating the centroid of each cluster based on the newly assigned data points. This continues until the centroids no longer move or the maximum number of iterations is reached. 📊🔍
#
# The "K" in K-means refers to the number of clusters you want to create. You can decide this through domain knowledge or by trial and error. 💭🔍

# %% [markdown]
# You may be wondering 🤔 how these centroids are calculated 🔢  in K-means clustering:

# %% [markdown]
# 🤖 **Initialization:** The algorithm starts by randomly assigning the K centroids, where K is the number of clusters specified by the user.
#
# 📊 **Assigning data points to clusters:** Each data point is then assigned to the nearest centroid, based on the Euclidean distance between the data point and the centroid. This creates K clusters.
#
# 🔍 **Recalculating centroids:** For each cluster, the algorithm calculates the mean of all the data points assigned to that cluster. This mean value becomes the new centroid for that cluster.
#
# 🔄 **Repeating until convergence:** Steps 2 and 3 are repeated until the centroids no longer change or a maximum number of iterations is reached. At this point, the algorithm has converged and the final centroids represent the center of each cluster.

# %% [markdown]
# ![56854k means clustering.png](data:image/png;base64,...)

# %% [markdown]
# One potential problem is that the algorithm initializes the centroids randomly, so different initializations may result in different cluster assignments and centroids. To solve this issue, the algorithm is often run multiple times with different random initializations, and the best clustering is chosen based on some criterion such as the sum of squared distances between data points and their assigned centroid. 🔄💡
#
# Despite its limitations, K-means clustering is widely used in industry for various applications such as customer segmentation, fraud detection, and anomaly detection. For example, a bank might use K-means clustering to group customers 👥 based on their financial behavior 💵 and identify potential fraudsters 🤡 or risky clients. It's even useful in image segmentation to identify regions of similar color or texture for object recognition or image analysis! 📷
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Generate synthetic data with 3 clusters
X, _ = make_blobs(n_samples=300, centers=3, random_state=42)

# Create and fit the KMeans model
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)

# Get the cluster centers and labels
cluster_centers = kmeans.cluster_centers_
labels = kmeans.labels_

# Plot the data points and cluster centers
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', edgecolor='k', s=50)
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='red', marker='X', s=200, label='Cluster Centers')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-means Clustering')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# In this example, we use scikit-learn's make_blobs function to generate synthetic data with three clusters. We then create a KMeans model with n_clusters=3 (since we know the data has three clusters) and fit it to the data. The cluster_centers_ attribute gives us the coordinates of the cluster centers, and the labels_ attribute provides the cluster assignments for each data point.
#
# Finally, we plot the data points with different colors corresponding to their cluster assignments and mark the cluster centers with red "X" markers. It shows  a scatter plot with three distinct clusters and the corresponding cluster centers identified by the K-means clustering algorithm.

# %% [markdown]
# ### **Hierarchical Clustering**

# %% [markdown]
# 🌳💻 Hierarchical clustering is another popular unsupervised learning algorithm used for clustering. Unlike K-means clustering, which requires the number of clusters to be specified beforehand, hierarchical clustering does not require any prior knowledge of the number of clusters. Instead, it creates a hierarchy of clusters by successively merging or dividing existing clusters based on their similarity.

# %% [markdown]
# 🌟👥 There are two main types of hierarchical clustering: agglomerative and divisive.

# %% [markdown]
# **Agglomerative clustering**, also known as bottom-up clustering, ⬆ starts with each data point in its own cluster and successively merges the closest clusters until all data points belong to a single cluster. The distance between clusters can be measured using various metrics such as Euclidean distance or correlation distance.
#
# **Divisive clustering**, also known as top-down clustering, ⬇ starts with all data points in a single cluster and successively divides the cluster into smaller sub-clusters until each data point is in its own cluster. This process is typically guided by a hierarchical tree structure that represents the division of the clusters.
#
# Both agglomerative and divisive clustering can be applied to a wide range of data types and are useful for exploring the structure of complex data sets.  The choice between the two depends on the specific problem at hand and the desired level of granularity in the clustering results. 🤔

# %% [markdown]
# ![Clustering1.gif](data:image/gif;base64,...)

# %% [markdown]
# 📊🌿 The result of hierarchical clustering is typically represented as a dendrogram, which is a tree-like diagram that shows the hierarchy of clusters. The dendrogram can be cut at different heights to obtain different numbers of clusters, depending on the desired granularity of the clustering.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# Generate synthetic data
np.random.seed(42)
X = np.random.rand(10, 2)

# Perform hierarchical clustering
Z = linkage(X, method='ward')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram')
plt.show()

# %% [markdown]
# In this example, we generate a small dataset X with 10 data points and 2 features. Then, we perform hierarchical clustering using the linkage function from scipy.cluster.hierarchy. The method='ward' argument specifies that we want to use the Ward linkage method, which minimizes the variance when merging clusters.
#
# The linkage function computes the distances between data points and iteratively merges the closest pairs of clusters until all data points are in one cluster. The result of hierarchical clustering is a matrix Z containing the information about the merging process.
#
# Finally, we plot the dendrogram using matplotlib to visualize the clustering process. The dendrogram illustrates the hierarchical structure of the clusters and the distances at which clusters are merged. By cutting the dendrogram at different heights, we can obtain different cluster assignments.

# %% [markdown]
# Advantages of Hierarchical Clustering:
#
# 🧬🔬 Biology: Hierarchical clustering can be used to analyze gene expression data to identify groups of genes that are co-expressed, which can provide insights into biological processes and disease mechanisms.
#
# 💰🛍️ Marketing: Hierarchical clustering can be used to segment customers based on their purchasing behavior or demographic information, which can be used to develop targeted marketing campaigns.
#
# 📱👥 Social Networks: Hierarchical clustering can be used to identify communities within social networks, which can provide insights into the structure of the network and the behavior of its users.
#
# 🖼️👁️‍🗨️ Computer Vision: Hierarchical clustering can be used for image segmentation, where similar regions in an image are grouped together based on their pixel values or features.

# %% [markdown]
# Limitations of Hierarchical Clustering:
#
# 🚫 Scalability: Hierarchical clustering can be computationally expensive for large datasets, especially for agglomerative clustering, which requires computing the distance between all pairs of data points.
#
# 📈 Sensitivity to Noise: Hierarchical clustering is sensitive to outliers and noise in the data, which can lead to suboptimal clustering results.
#
# 💬 Subjectivity: The choice of distance metric and linkage method can affect the resulting dendrogram and the number of clusters obtained, which can be subjective.
#
# 🤝 Lack of Flexibility: Once the hierarchy of clusters is determined, it cannot be easily modified or updated without recomputing the entire clustering, which can be time-consuming.
#
# ---

# %% [markdown]
# ###**Density-based Clustering**

# %% [markdown]
# Hey hey, have you heard of density-based clustering? 🤔 It's a fancy method that groups data points based on their density and proximity. Basically, if points are packed closely together, they're considered a cluster, while sparse areas are considered noise. 🌟

# %% [markdown]
# 🔍 One of the most popular density-based clustering algorithms is DBSCAN (Density-Based Spatial Clustering of Applications with Noise). 📊 The DBSCAN algorithm defines clusters as regions of the data space where there are many data points close together, separated by regions of lower point density. 💡 DBSCAN works by defining two parameters: epsilon (ε), which represents the radius of the neighborhood around each point, and minPts, which represents the minimum number of points required to form a dense region or cluster.

# %% [markdown]
# 🚀 The DBSCAN algorithm starts with a random data point and finds all other data points within its epsilon radius. If the number of points within the radius is greater than or equal to the minPts parameter, a new cluster is formed. 🎯 If the number of points within the radius is less than minPts, the data point is labeled as noise or an outlier.

# %% [markdown]
#  Here's how it works:
#
# * Choose a random data point.
#
# * Find all other data points that are within a certain distance (epsilon) of the chosen point. These data points are considered "neighbors" of the chosen point.
#
# * If the number of neighbors is greater than or equal to a specified threshold (minPts), then the chosen point is considered a "core point" and a new cluster is formed.
#
# * Expand the cluster by finding all neighbors of the core point, and checking if they also have enough neighbors to be considered core points.
#
# * Repeat steps 3-4 until no more core points can be found.
#
# * Any remaining unclustered points are considered noise or outliers.
#
# The algorithm is efficient because it avoids computing distances between all pairs of data points, and instead focuses on local density. DBSCAN is also robust to noise and outliers, and can handle non-linear and non-spherical clusters.

# %% [markdown]
# 🔍 **Applications of density-based clustering include:**
#
# * Identifying clusters in spatial data such as 🌍📍 GPS locations or geographic regions. 🗺️
#
# * Anomaly detection in network traffic or sensor data. 🚨
# Identifying groups of customers with similar purchasing behavior or preferences. 🛍️
#
# * Segmentation of biological data such as gene expression data. 🧬
#
# **However, density-based clustering also has some limitations:**
#
# * It can be sensitive to the choice of parameters, especially the epsilon radius and minPts values. 🤔
#
# * It may not work well on data with varying densities or with data points that are highly interconnected. 🤷‍♀️
# * It can be computationally expensive for large datasets. 💻
#
# ---

# %% [markdown]
# ##**Activity 1: Fill in the Blanks**
# 1. Hierarchical clustering is a popular unsupervised learning algorithm that creates a hierarchy of clusters by _______________ or _______________ existing clusters based on their similarity.
#
# 2. In K-means clustering, the "K" refers to the _______________.
#
# 3. Agglomerative clustering, also known as _______________ clustering, starts with each data point in its own cluster and successively _______________ the closest clusters until all data points belong to a single cluster.

# %% [markdown]
# ###**Activity 1 Answers:**
#
# 1. Merging, Dividing
# 2. Number of clusters
# 3. Bottom-up clustering, merges

# %% [markdown]
# ## **Dimensionality Reduction Techniques**

# %% [markdown]
# 🤖 Let's talk about dimensionality reduction! It's like decluttering your dataset by getting rid of unnecessary features. This can help make your data more manageable, reduce noise, and help prevent overfitting in your models. It's like Marie Kondo for data! 🧹

# %% [markdown]
# 🔍📊 Dimensionality reduction is the process of reducing the number of variables or features in a dataset. It is commonly used in machine learning and data analysis to simplify datasets and remove noise or redundant information, which can improve model performance and reduce the risk of overfitting.
#
# There are two main types of dimensionality reduction techniques: feature selection and feature extraction.

# %% [markdown]
# ![features_1-1150x548.png](data:image/png;base64,...)

# %% [markdown]
# **Feature Selection:**
# 🔍Feature selection involves picking out the most relevant features and ditching the rest.
#
# It involves 🔎 selecting a subset of the original features that are most relevant to the problem being solved. The 🏆 goal is to retain only the most informative features and ❌ discard the rest. This can be done through various methods such as  filtering, wrapping, or embedding.
#
# Filtering methods use 🔢 statistical techniques to evaluate the relevance of each feature and ✅ select the most important ones. Wrapping methods involve training a model using different subsets of features and selecting the subset that results in the best model performance. Embedding methods incorporate feature selection as part of the model training process.

# %% [markdown]
# **Feature Extraction:** 💡Feature extraction, on the other hand, creates brand new features that better capture the essence of the original data.
#
#
# It involves creating  new features that capture the most important information in the ⏯ original features. This is done by transforming the original features into a new set of features that better represents the underlying 🏗 structure of the data.

# %% [markdown]
# One popular feature extraction technique is **Principal Component Analysis (PCA)**, which transforms the original features into a new set of orthogonal features called principal components.
#
# **t-SNE (t-Distributed Stochastic Neighbor Embedding)** is another popular dimensionality reduction technique used for visualizing high-dimensional data in a low-dimensional space.
#
# ---

# %% [markdown]
# ### **Principal Component Analysis**

# %% [markdown]
# 🔍📉 Principal Component Analysis (PCA) is a technique that shrinks big data into a smaller and manageable size while preserving the most critical information.

# %% [markdown]
# Principal Component Analysis (PCA) is a widely used dimensionality reduction technique that transforms high-dimensional data into a lower-dimensional representation while preserving the most important information in the original data.
#
# 📊 PCA works by identifying the principal components (PCs) of the dataset, which are new variables that capture the maximum amount of variance in the original data. The first principal component captures the most variance, followed by the second, third, and so on.
#
# 💻 The process of computing principal components involves finding the eigenvectors and eigenvalues of the covariance matrix of the data. The eigenvectors represent the directions of maximum variance in the data, while the eigenvalues represent the magnitude of the variance in each direction.
#
# Once the principal components are identified, they can be used to transform the original data into a lower-dimensional space. The transformed data will have fewer dimensions, but will retain most of the variation present in the original data.

# %% [markdown]
# Implementing PCA typically involves the following steps:
#
# **Data preprocessing:** The first step is to preprocess the data by centering it around its mean and scaling it to have unit variance. This ensures that all features are on the same scale and prevents features with larger variances from dominating the analysis.
#
# **Computing the covariance matrix:** Next, the covariance matrix is computed based on the preprocessed data. The covariance matrix is a measure of the linear relationship between pairs of features in the data.
#
# **Calculating the eigenvectors and eigenvalues:** The eigenvectors and eigenvalues of the covariance matrix are then calculated. The eigenvectors represent the directions in which the data varies the most, while the eigenvalues represent the amount of variance explained by each eigenvector.
#
# **Choosing the principal components:** The principal components are then selected based on the eigenvalues, with the first principal component being the one that explains the most variance in the data, the second principal component being the one that explains the second most variance, and so on.
#
# Projecting the data onto the principal components: Finally, the data is projected onto the principal components to obtain the transformed dataset in the lower-dimensional space.

# %% [markdown]
# ![pca2.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# Load an example dataset (you can replace this with your own data)
data = load_iris()
X, y = data.data, data.target

# Apply PCA to reduce data dimensions to 2D
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Create a scatter plot to visualize PCA representation
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap=plt.cm.tab10)
plt.title("PCA Representation")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.colorbar()

# Show the plot
plt.show()

# %% [markdown]
# **Applications:**
#
# 💻 PCA has many applications, such as data compression, visualization, and feature extraction. For example, in image processing, PCA can be used to extract features from images, which can then be used for tasks such as image classification or object recognition.
#
# Limitations:
#
# 👎 However, one limitation of PCA is that it assumes a linear relationship between the variables, which may not always be the case in real-world datasets. Also, the interpretation of the principal components may not always be straightforward, as they are linear combinations of the original variables.
#
# ---

# %% [markdown]
# ### **t-SNE (t-Distributed Stochastic Neighbor Embedding)**

# %% [markdown]
# ⏯ t-SNE (t-Distributed Stochastic Neighbor Embedding) is a dimensionality reduction technique that is commonly used for visualizing high-dimensional data in a lower-dimensional space.

# %% [markdown]
# Unlike traditional dimensionality reduction techniques such as PCA, t-SNE focuses on preserving the local structure of the data, rather than the global structure. It does this by modeling the similarity between points in the high-dimensional space and the low-dimensional space using probability distributions.
#
# In the t-SNE algorithm, each high-dimensional data point is initially assigned a probability distribution that reflects its similarity to other points. The algorithm then tries to find a low-dimensional representation of the data where these probabilities are preserved as closely as possible. This is done by iteratively adjusting the positions of the low-dimensional points until the similarity between the high-dimensional and low-dimensional probability distributions is maximized.
#
# The result of t-SNE is a 2D or 3D representation of the data, where similar points are placed closer together and dissimilar points are farther apart. This makes it easier to visualize and interpret the structure of the data. t-SNE is commonly used in fields such as computer vision, natural language processing, and bioinformatics.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.manifold import TSNE

# Load an example dataset (you can replace this with your own data)
data = load_iris()
X, y = data.data, data.target

# Apply t-SNE to reduce data dimensions to 2D
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# Create a scatter plot to visualize t-SNE representation
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap=plt.cm.tab10)
plt.title("t-SNE Representation")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.colorbar()

# Show the plot
plt.show()

# %% [markdown]
# **Working:**
#
# * t-SNE works by first measuring the pairwise similarity between data points in the high-dimensional space using a Gaussian kernel. It then constructs a probability distribution over pairs of points, where the probability of selecting a pair is proportional to their similarity.
#
# * Next, t-SNE constructs a similar probability distribution over pairs of points in a low-dimensional space, such that the similarities in the low-dimensional space closely match the similarities in the high-dimensional space.
#
# * Finally, t-SNE uses gradient descent to minimize the difference between the two probability distributions, adjusting the positions of the points in the low-dimensional space until a suitable embedding is found.

# %% [markdown]
# **Applications:**
#
# * t-SNE is often used in fields such as 👁 bioinformatics, 🔤 natural language processing, and 🤖 computer vision.
#
# **Limitations:**
#
# * One limitation of t-SNE is that it can be computationally expensive, especially for large datasets.
# * It can also be sensitive to the choice of parameters, such as the perplexity, which controls the balance between local and global structure in the embedding.
# * Additionally, t-SNE does not preserve distances well, meaning that the distance between two points in the low-dimensional space may not be a reliable measure of their similarity in the high-dimensional space.
#
# ---

# %% [markdown]
# ### **UMAP (Uniform Manifold Approximation and Projection)**

# %% [markdown]
# 🔬📊👀 Umap, short for Uniform Manifold Approximation and Projection, is a dimensionality reduction technique that can be used for visualizing high-dimensional data in a lower-dimensional space. Umap is similar to t-SNE in that it also focuses on preserving the local structure of the data. 🌐📈🧐

# %% [markdown]
# 🤔🔍📊 Umap works by constructing a weighted graph representation of the high-dimensional data, where each data point is represented by a node in the graph. 📊🔗 The edges between nodes are weighted based on the similarity between the corresponding data points. 💡🌐 Umap then uses a technique called manifold learning to embed the graph into a lower-dimensional space, while preserving the topological structure of the data. 🚀📉👨‍🔬

# %% [markdown]
# ![clustering_31_1 (1).jpg](data:image/jpeg;base64,...)

# %%
# !pip install matplotlib umap-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82813 sha256=da521fa886c4accf07b275f5be40b237104ccaf675d67474091a7101591b2d5a
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
# ...
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55621 sha256=ac737b1bdc91161e0295feaa2da3fbec9bc9339cc8e6fd868bace7cf5d832475
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built umap-learn pynndescent
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from umap import UMAP

# Load an example dataset (you can replace this with your own data)
data = load_iris()
X, y = data.data, data.target

# Apply UMAP to reduce data dimensions to 2D
umap = UMAP(n_components=2, random_state=42)
X_umap = umap.fit_transform(X)

# Create a scatter plot to visualize UMAP representation
plt.figure(figsize=(8, 6))
plt.scatter(X_umap[:, 0], X_umap[:, 1], c=y, cmap=plt.cm.tab10)
plt.title("UMAP Representation")
plt.xlabel("UMAP Component 1")
plt.ylabel("UMAP Component 2")
plt.colorbar()

# Show the plot
plt.show()

# %% [markdown]
# **Working:**
#
# 👨‍🔬📊 UMAP works by constructing a high-dimensional graph representation of the input data, where each data point is represented as a node in the graph. 🔗📈 The edges between the nodes are weighted based on the similarity between the data points they represent. 💡🌐 UMAP uses a fuzzy topological structure to capture the relationships between data points, allowing it to handle complex and nonlinear relationships.
#
# 🔍📉 Once the graph is constructed, UMAP optimizes a low-dimensional representation of the data using a stochastic gradient descent algorithm. 🤖💻 The optimization process aims to find a low-dimensional embedding that preserves the global structure of the original high-dimensional data. 🎯 UMAP uses a cost function based on the cross-entropy between the high-dimensional graph and the low-dimensional representation to guide the optimization process. 📉🚀

# %% [markdown]
# **Advantages:**
#
# * One advantage of Umap over t-SNE is that it is faster and more scalable, making it suitable for analyzing larger datasets. 🐎💻
# * Umap also has more flexibility in the choice of distance metrics and can handle missing data, which can be an issue with some other dimensionality reduction techniques. 📊🤝🔍
#
# **Limitations:**
#
# Like any dimensionality reduction technique, UMAP has certain limitations. 🚫🌐
#
# *  UMAP may not always preserve global structure as well as some other techniques like PCA. This means that some information about the original dataset may be lost during the dimensionality reduction process.
#
# * UMAP is a computationally 💻💰 expensive technique, particularly for larger datasets
#
# * Like t-SNE, the choice of hyperparameters such as the number of neighbors and the distance metric can have a significant impact on the results of UMAP, and may require some experimentation to find the optimal settings. 🤝🧪🔬
#
# ---

# %% [markdown]
# ##**Activity 2: True or False**
# 1. t-SNE is a dimensionality reduction technique that focuses on preserving the global structure of high-dimensional data.True or False:
#
# 2.  t-SNE models the similarity between points in the high-dimensional space and the low-dimensional space using probability distributions.True or False:
#
# 3. The result of t-SNE is a lower-dimensional representation of the data, where similar points are placed farther apart and dissimilar points are placed closer together.True or False:

# %% [markdown]
# ### **Activity 2 Answers**
# 1. False
# 2. True
# 3.
# False

# %% [markdown]
# ## **Recommendation System**

# %% [markdown]
# ![recommender system.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 🤖👥💡 Recommendation system is a type of unsupervised learning algorithm used in e-commerce, social media, and other online platforms to suggest products, services, or content to users based on their past interactions or preferences. 🛍️📱💻 The goal of a recommendation system is to provide personalized recommendations that are relevant and useful to each individual user. 🎁💡

# %% [markdown]
# One common approach to building a recommendation system is to use collaborative filtering, which involves analyzing user behavior and interactions to find patterns and similarities between users. Collaborative filtering can be based on either user behavior or item attributes.

# %% [markdown]
# ### **Collaborative Filtering**

# %% [markdown]
#  Collaborative filtering is a popular technique used in recommendation systems 🤖 to recommend items to users 👥💡based on their past interactions with the system and the behavior of similar users. 🔍👥🛍️ It is an unsupervised learning approach that relies on finding patterns and similarities in the interactions of users and items in a given dataset.

# %% [markdown]
# There are two main types of collaborative filtering: user-based and item-based.
#
# In user-based collaborative filtering, the system recommends items to a user based on the behavior of similar users. 🤝👥 The system first finds users who have similar interests and preferences to the target user, based on their interactions with the system. It then recommends items that the similar users have interacted with, but the target user has not.

# %% [markdown]
# In item-based collaborative filtering, the system recommends items to a user based on the behavior of similar items. 🔗🛍️ The system first identifies items that are similar to the ones that the target user has interacted with. It then recommends the most similar items that the target user has not interacted with.

# %% [markdown]
# Another approach to recommendation systems is content-based filtering, which involves analyzing the attributes of the items themselves to find similarities between them. For example, if a user has purchased a specific type of clothing, the system may recommend other clothing items that are similar in style, color, or material.
#
# In both collaborative and content-based filtering, the system uses machine learning algorithms to analyze user data and item attributes, and to predict which items a user is most likely to enjoy. The system then recommends these items to the user in a personalized way, often using ranking or scoring systems to prioritize recommendations based on relevance and importance.

# %% [markdown]
# ![1_mz9tzP1LjPBhmiWXeHyQkQ.png](data:image/png;base64,...)

# %% [markdown]
# **Application & Limitations:**
#
# Collaborative filtering has a wide range of applications, including product recommendations, movie recommendations, and music recommendations. 🎁🎬🎶
#
# However, it also has some limitations, such as the cold-start problem, where new users or items have no or limited interaction history, and the sparsity problem, where the interaction matrix is sparse, making it challenging to find meaningful patterns and similarities. 🤔🔍

# %% [markdown]
# ### **Matrix Factorization**

# %% [markdown]
# One popular method for implementing collaborative filtering is matrix factorization. 🧮 Matrix factorization involves breaking down the user-item interaction matrix into two lower-dimensional matrices: a user matrix and an item matrix. 🎥🎵 These matrices are then multiplied together to predict the ratings or preferences of each user for each item.

# %% [markdown]
# ![applsci-10-04926-g001.png](data:image/png;base64,...)

# %% [markdown]
# Matrix factorization is a technique used in recommendation systems to extract hidden features or latent factors from a user-item interaction matrix. It works by decomposing the original matrix into two or more lower-dimensional matrices that can be used to make recommendations.
#
# The idea behind matrix factorization is that each user and each item in the interaction matrix can be represented as a vector of latent factors, such as interests or preferences. These latent factors are not directly observable but can be inferred from the patterns of user-item interactions in the matrix.

# %% [markdown]
# The decomposition of the original matrix can be achieved using different methods, such as Singular Value Decomposition (SVD), Non-negative Matrix Factorization (NMF), or Alternating Least Squares (ALS). These methods differ in their mathematical properties and computational efficiency.
#
# Once the user and item latent factors have been obtained, they can be used to make personalized recommendations. For example, to recommend items to a user, the system can compute the similarity between the user's latent factor vector and the latent factor vectors of all items in the dataset. The items with the highest similarity scores can then be recommended to the user.

# %% [markdown]
# **Application:**
#
# Matrix factorization is particularly useful in cases where the user-item interaction matrix is sparse, meaning that many users have not interacted with many items. By reducing the dimensionality of the matrix, matrix factorization can help alleviate the sparsity problem and improve recommendation accuracy.
#
# **Limitation:**
#
# However, matrix factorization also has some limitations. It assumes that the user-item interactions are only influenced by the latent factors, and not by other factors such as context or temporal effects. Additionally, it can be computationally expensive for large datasets, and the quality of the recommendations may depend on the quality of the input data.
#
# ---

# %% [markdown]
# ## **Activity 3: Guess the Word**
# 1. I am a technique used in recommendation systems to extract hidden features or latent factors from a user-item interaction matrix. My goal is to decompose the original matrix into lower-dimensional matrices for making personalized recommendations.Who am I?
#
# 2. I am a mathematical method that decomposes the original matrix into two or more lower-dimensional matrices. I am particularly useful in cases where the user-item interaction matrix is sparse, and I can help improve recommendation accuracy by alleviating the sparsity problem.Who am I?
#
# 3. I am a limitation of matrix factorization. I assume that user-item interactions are influenced solely by latent factors and not by other factors like context or temporal effects. Additionally, I can be computationally expensive for large datasets, and my recommendations' quality depends on the input data's quality.Who am I?

# %% [markdown]
# ### **Activity 3 Answers**
# 1. Matrix Factorization.
# 2. Singular Value Decomposition (SVD), Non-negative Matrix Factorization (NMF), Alternating Least Squares (ALS).
# 3. Limitation of Matrix Factorization.

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ###🧠 **What did you learn?** 🤔

# %% [markdown]
# Congratulations, students! You've completed the 'Unsupervised Models' course, and now it's time to review what you've learned. Here's a summary of the key concepts and skills you've gained:
#
# 🔍 You've developed a solid understanding of unsupervised learning algorithms and their applications in various domains. Clustering algorithms like k-Means, hierarchical clustering, and DBSCAN enable you to identify natural structures in the data, while dimensionality reduction techniques like PCA, t-SNE, and UMAP help you visualize high-dimensional data and improve model performance.
#
# 🏙️ You've explored recommendation systems and learned about collaborative filtering and matrix factorization methods. These powerful techniques allow you to build personalized recommendation engines that analyze user-item interactions and provide valuable suggestions in e-commerce and content platforms.
#
# 💻 You've gained hands-on experience in implementing unsupervised algorithms using Python libraries like Scikit-Learn. You can now confidently apply these techniques to real-world datasets and use them to gain insights, uncover hidden patterns, and make data-driven decisions in various domains.
#
# 🚀 With these skills and knowledge under your belt, you're well-equipped to tackle a wide range of data analysis and problem-solving tasks using unsupervised learning. Keep up the great work, and keep exploring the exciting world of machine learning!

# %% [markdown]
# ### **Best Practices/Tips**

# %% [markdown]
# 💻 Practice hands-on coding: To master unsupervised learning, practice implementing various algorithms and techniques using Python libraries like Scikit-Learn. The more you practice, the more confident you'll become in applying these methods to real-world data.
#
# 📊 Visualize your data: Use data visualization techniques to gain insights into the structure and patterns of your data. Visualization can help you identify clusters, outliers, and relationships among features.
#
# 🧹 Handle missing values and outliers carefully: Properly handle missing data and outliers in your dataset to avoid biased results. Use appropriate imputation techniques and outlier handling methods, such as winsorization or removing extreme outliers.
#
# 📏 Choose the right evaluation metrics: Select evaluation metrics suitable for the specific unsupervised learning task at hand. For clustering, metrics like silhouette score and Davies-Bouldin index can be informative, while for dimensionality reduction, you may use explained variance or reconstruction error.
#
# 📚 Keep exploring algorithms: Don't limit yourself to just a few algorithms. Experiment with different clustering and dimensionality reduction algorithms to find the most suitable ones for your data.
#
# 🤝 Collaborate and seek feedback: Engage with peers, mentors, or online communities to exchange ideas and gain insights from others. Collaboration can lead to new perspectives and creative solutions.
#
# 🔍 Fine-tune hyperparameters: If using algorithms with hyperparameters, perform hyperparameter tuning to optimize the model's performance. Use techniques like grid search or random search to find the best hyperparameters.
#
# 🧪 Experiment with feature engineering: Try different feature engineering techniques to create more informative features from your data. Feature engineering can enhance the performance of unsupervised models.
#
# 🚀 Keep learning and stay updated: Unsupervised learning is a rapidly evolving field. Stay up-to-date with the latest research, tools, and techniques to leverage the most advanced methods for your projects.
#
# 📈 Evaluate model interpretability: For some applications, interpretability of unsupervised models is essential. Choose algorithms that provide interpretable results to gain meaningful insights from the model's outputs.

# %% [markdown]
# ### **Shortcomings**

# %% [markdown]
# ❌ Lack of Ground Truth: Unlike supervised learning, unsupervised learning lacks a clear objective function or ground truth to evaluate model performance. This can make it challenging to assess the accuracy and quality of the results.
#
# 😕 Subjectivity in Interpretation: Interpreting the results of unsupervised learning algorithms can be subjective and open to different interpretations. Determining the optimal number of clusters or the significance of extracted dimensions may rely on human judgment.
#
# 🔄 Sensitivity to Preprocessing: Unsupervised models can be sensitive to data preprocessing choices, such as scaling, outlier handling, and feature engineering. Small changes in preprocessing steps may lead to significantly different outcomes.
#
# 🚫 Scalability: Some unsupervised algorithms, especially those based on distance calculations, can become computationally expensive and inefficient for large datasets with high dimensions.
#
# 📈 Curse of Dimensionality: In high-dimensional spaces, unsupervised learning may face the "curse of dimensionality," where the data becomes sparse, making it challenging to find meaningful patterns.
#
#    Identifying Optimal Clusters: Selecting the optimal number of clusters (k) in clustering algorithms like k-Means can be difficult. There is no definitive method for determining the ideal k, and different evaluation metrics may lead to conflicting results.
#
# 🤖 Overfitting: Unsupervised learning models are not immune to overfitting, especially when dealing with complex datasets or using algorithms with many hyperparameters.
#
# 📭 Lack of Labels: Since unsupervised learning operates on unlabeled data, it may not be suitable for tasks where labeled data is essential for understanding specific patterns or making accurate predictions.
#
# 🕵️ Incomplete Anomaly Detection: Unsupervised models may struggle to identify rare or novel anomalies effectively, as they are often overshadowed by more dominant patterns in the data.
#
# 🧩 Interpretability Challenges: Some unsupervised learning algorithms, such as neural networks or non-linear dimensionality reduction methods, may lack interpretability, making it challenging to explain the learned representations.

# %% [markdown]
# #**🧠Enhance Your Knowledge🧠**

# %% [markdown]
# ###🤖🌲**Mnemonic**🕵️‍♂️🦉
#
#
# Mnemonics are texts or devices that helps you to remember a concept. Here's a mnemonic to help you remember Indexing and Slicing

# %% [markdown]
# In the bustling metropolis of Dataville, a team of data analysts and market researchers, led by Sarah, worked for a renowned consulting firm named DataInsights. The firm was approached by a leading retail chain, GlobalMart, seeking help to optimize their product offerings and understand customer preferences better.
#
# Sarah and her team saw an opportunity to apply unsupervised learning to unravel the market trends and make data-driven decisions. They knew that by using clustering algorithms and dimensionality reduction, they could gain valuable insights from the vast amount of transaction and customer data collected by GlobalMart.
#
# First, they collected data on customers' purchasing behaviors, product preferences, and demographics. The data was massive, and the team needed to preprocess it to ensure accuracy and remove any noise.
#
# Next, they employed the "Cluster Seeker" algorithm to group customers based on their shopping habits and preferences. The algorithm identified distinct clusters of customers with similar buying patterns. They uncovered segments of loyal shoppers, occasional buyers, and bargain hunters.
#
# As they examined each cluster, they discovered surprising patterns. Some loyal shoppers preferred to buy premium brands, while others were drawn to discounted items. The occasional buyers showed interest in seasonal products. Armed with this knowledge, Sarah recommended personalized marketing strategies for each cluster.
#
# To further analyze the purchasing trends, the team utilized the "Dimension Magician" technique. This transformed the multidimensional data into a more concise representation while preserving essential characteristics.
#
# The Dimension Magician revealed a crucial finding – a new cluster emerged, comprising customers who were gradually shifting their preferences towards eco-friendly and sustainable products. This insight presented an opportunity for GlobalMart to expand their eco-conscious product range and appeal to this growing segment.
#
# With these actionable insights in hand, Sarah and her team collaborated closely with GlobalMart's marketing and product development departments. They designed targeted marketing campaigns for each customer cluster, tailored promotions, and optimized product placements within stores.
#
# Over the following months, GlobalMart witnessed a significant improvement in sales and customer satisfaction. The personalized approach to marketing created a more engaging shopping experience, driving customer loyalty and brand advocacy.
#
# Emboldened by their success, Sarah and her team continued to use unsupervised learning to solve other business challenges. They applied clustering techniques to streamline inventory management, predict demand, and identify emerging market trends.
#
# In the end, the data-driven strategies powered by unsupervised learning transformed GlobalMart's business landscape. The partnership between DataInsights and GlobalMart became a symbol of innovation and efficiency, inspiring other businesses in Dataville to harness the power of data to thrive in the dynamic market landscape.
#
# And so, the practical application of unsupervised learning in Dataville continued to unfold, empowering businesses to make informed decisions, uncover hidden opportunities, and shape a prosperous future in the world of data-driven insights.

# %% [markdown]
# ###**📖Additional Reference Paper📖**

# %% [markdown]
# [8 Clustering Algorithms in Machine Learning that All Data Scientists Should Know](https://www.freecodecamp.org/news/8-clustering-algorithms-in-machine-learning-that-all-data-scientists-should-know/)
#
# [Dimensionality Reduction for Machine Learning](https://neptune.ai/blog/dimensionality-reduction)
#
# [Matrix Factorization Explained](https://www.mygreatlearning.com/blog/matrix-factorization-explained/)

# %% [markdown]
# #**Try it Yourself**

# %% [markdown]
# ### **Task 1: Working on assignment**

# %% [markdown]
# ####**Problem Statement** :  *Wine Customer Segmentation for Marketing Insights*
# You are a data scientist working for a winery, and your task is to perform customer segmentation based on chemical analysis results of wines. The winery wants to understand its customer base better to tailor marketing strategies and improve customer satisfaction.
#
# Dataset:
# The dataset you will use is the "Wine" dataset, which contains chemical analysis results of wines from different cultivars. The dataset has 13 features, such as alcohol content, malic acid, ash, and magnesium.
#
# Project Tasks:
#
# - Data Preprocessing:
#   - Load the "Wine" dataset from scikit-learn.
#   - Perform feature scaling using StandardScaler to bring all features to a similar scale.
#   - Optionally, explore the dataset using a visualization technique like PCA to gain insights into the data distribution.
#
# - Clustering Analysis:
#   - Implement k-Means clustering, hierarchical clustering, and DBSCAN algorithms to segment the wine samples based on their chemical analysis results.
#
#   - Choose an appropriate number of clusters for each algorithm based on business knowledge or use methods like the Elbow Method or Silhouette Score to determine the optimal number of clusters.
#
#   - Evaluate the clustering results using visualizations and, if applicable, metrics like the Silhouette Score.
#
# - Dimensionality Reduction and Visualization:
#   - Optionally, apply dimensionality reduction techniques like PCA, t-SNE, or UMAP to visualize the wine samples in 2D or 3D space.
#   - Analyze the visualizations to gain insights into the underlying patterns and relationships between different wine samples.
#
# - Customer Segmentation Insights:
#   - Interpret the clustering results to identify distinct customer segments based on the wine samples' chemical characteristics.
#   - Analyze the characteristics of each segment and provide insights to the winery for targeted marketing strategies, product recommendations, or customer engagement improvements.

# %%
#Write your solution here

# %% [markdown]
# ### **Task 2: Community Engagement**
# Which dimensionality reduction technique did you find most interesting & Why? Share the vizualization charts of Clustering Analysis in your Cohort group at AlmaBetter Community Platform.
