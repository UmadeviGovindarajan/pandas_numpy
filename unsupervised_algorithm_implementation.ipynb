# %% [markdown]
# <a href="https://colab.research.google.com/github/UmadeviGovindarajan/pandas_numpy/blob/main/unsupervised_algorithm_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Session Flow**
# * **Learning Objective**
#  - Introduction
#  - Theme
#  - Primary Goals
# * **Learning Material**
#   * Preprocesssing Unsupervised Data
#   * Activity 1: Fill in the Blanks
#    * Data Cleaning
#    * Data Scaling/ Normalization
#    * Min-Max Scaling
#    * Standardization
#   * Activity 2: True or False
#   * Implementing Unsupervised Algorithms
#   * Evaluating Clustering and Dimensionality Reduction Models
#    * Silhouette Score
#    * Elbow Method
#    * Reconstruction Error
#   * Activity 3: Match the following
#   * Deploying unsupervised models in production
#    * Batch Proccessing
#    * Real-Time Streaming
#   * Best practices for working with unsupervised data
#    * Outlier Detection
#    * Data Scaling
#    * Handling Imbalanced Datasets
#   * Activity 4: Guess the word
# * **Summary**
#  - What did you learn?
#  - Best Practices/Tips
#  - Shortcomings
# * **Enhance Your Knowledge**
#   - Additional Reference Paper
#   - Mnemonic
# * **Try it Yourself**
#   - Take Home Assignment

# %% [markdown]
# #**Learning Objective**

# %% [markdown]
# 👋 Hey there!!
#
# 🤖💡Welcome to the realm of unsupervised learning, where algorithms become intelligent detectives, uncovering hidden patterns and structures in data without any guiding labels. Today, we'll embark on an exciting journey into implementing unsupervised algorithms, where the magic of artificial intelligence comes to life! 🚀✨
#
#
# ##🔍📊 **Introduction** 🔍📊
#
#
#
# Unsupervised Algorithms are like explorers of the unknown, uncovering hidden patterns and structures within data without any predefined labels. This powerful branch of machine learning finds its application in various domains, from customer segmentation to anomaly detection. 🕵️‍♀️🌌
#
# Unlike traditional methods that require labeled data, Unsupervised Algorithms have the remarkable ability to unravel patterns and structures without explicit guidance, making them a key tool in modern data analysis and decision-making. From customer segmentation to anomaly detection and market basket analysis, the applications of Unsupervised Learning are boundless and impactful across various industries.
#
# Through real-life examples, participants will witness how these algorithms have transformed businesses and enriched our understanding of complex systems. As learners progress, they will master the essential data scaling and preprocessing techniques that prepare raw data for the unsupervised exploration, ensuring high-quality input for accurate insights. With hands-on projects and practical application, participants will gain confidence in implementing clustering and dimensionality reduction methods, detecting anomalies, and interpreting results effectively.
#
# The journey culminates in evaluating model performance and anticipating future trends in the ever-evolving landscape of Unsupervised Learning, equipping learners with the tools to unleash data's secrets and make data-driven decisions with confidence and precision. 🕵️‍♀️🌌🚀
#
# ##**Theme:**
#
# It is estimated that data scientists spend around 60-80% of their time on data preprocessing tasks. These preprocessing techniques help ensure that the data is in the correct format, free from errors and missing values, and ready for further analysis using machine learning algorithms or other data-driven techniques.
# Unsupervised Machine Learning is a powerful tool that allows us to uncover valuable insights from data without the need for explicit labels.
#
# For Instance, analyzing customer shopping behavior to segment them into distinct groups based on their preferences, like finding movie preferences to suggest personalized film recommendations on a streaming platform. Learners will master Data Scaling and Preprocessing skills by transforming raw data, such as cleaning a messy room, organizing it for easier access, and preparing it for analysis.
#
# By delving into clustering algorithms, they'll uncover patterns, much like organizing a wardrobe based on clothing types, and use dimensionality reduction techniques to simplify data, similar to creating a concise shopping list for grocery items. Empowered with these skills, will interpret hidden patterns like understanding traffic flow patterns to optimize city planning. 🛍️🔍
#
# ##**Primary Goals 🎯:**
#
#  Master Unsupervised Learning Techniques: Develop a solid understanding of various unsupervised learning algorithms, including clustering and dimensionality reduction methods.
#
# 2️⃣ Implement Algorithms using Python: Gain practical experience in implementing unsupervised learning algorithms using Python libraries like Scikit-Learn and other relevant tools.
#
# 3️⃣ Preprocess Data Effectively: Learn essential data preprocessing techniques specific to unsupervised learning, such as normalization, standardization, and handling missing values.
#
# 4️⃣ Evaluate Model Performance: Understand and apply evaluation metrics like silhouette score, elbow method, and reconstruction error to assess the quality of clustering and dimensionality reduction models.
#
# 6️⃣ Handle Data Challenges: Explore best practices for outlier detection, data scaling, and addressing imbalanced datasets commonly encountered in unsupervised learning projects.
#
# 7️⃣ Real-World Applications: Apply unsupervised algorithms to real-world datasets, gaining insights and uncovering patterns in data from various domains.
#
# 8️⃣ Develop Problem-Solving Skills: Strengthen your problem-solving abilities by tackling diverse unsupervised learning tasks, from data preprocessing to model deployment.

# %% [markdown]
# #**📖Learning Material📖**

# %% [markdown]
# ## **Preprocessing Unsupervised Data**

# %% [markdown]
# Preprocessing is an essential step in machine learning, and it plays a crucial role in preparing the data for analysis. When it comes to unsupervised learning, where the focus is on finding patterns or structures in the data without labeled target variables, preprocessing becomes even more important. In this introduction, we'll explore the basics of preprocessing unsupervised data. 🔄🔍
#
# The goal of preprocessing unsupervised data is to clean, transform, and prepare the data in a way that allows unsupervised learning algorithms to extract meaningful insights. These algorithms, such as clustering or dimensionality reduction techniques, rely on the quality and suitability of the input data. ✨💡

# %% [markdown]
# ![darae.png](data:image/png;base64,...)

# %% [markdown]
# Some common preprocessing steps for unsupervised data include:
#
# **Data Cleaning:** Handle missing values, remove outliers, and deal with any inconsistencies or errors in the data. 🧹📊
#
# **Data Scaling/Normalization:** Scale the numerical features to a common range to prevent certain features from dominating the analysis due to their larger scales. This ensures fair comparisons between different features. 📏⚖️
#
# **Feature Selection:** Identify and select the most relevant features for analysis. This can involve techniques like variance thresholding, correlation analysis, or dimensionality reduction methods. 🎯🔍
#
# **Dimensionality Reduction:** If the dataset has a large number of features, dimensionality reduction techniques like Principal Component Analysis (PCA) or t-SNE can be used to reduce the number of dimensions while preserving the most important information. 📉📈
#
# Data Encoding: Convert categorical variables into numerical representations that can be processed by unsupervised learning algorithms. This can be achieved through techniques like one-hot encoding or label encoding. 🧮🔢

# %% [markdown]
# ###**Activity 1: Fill in the Blanks**
#
# 1. In data preprocessing for unsupervised learning, ___________ can be used to reduce the number of dimensions while preserving important information in high-dimensional datasets.
#
# 2. To prevent certain features from dominating the analysis due to their larger scales, it is essential to perform ___________ on numerical features, ensuring fair comparisons between different features.
#
# 3. In data cleaning for unsupervised data, one of the important steps is to handle ___________ by using techniques such as imputation.

# %% [markdown]
# #### **Activity 1 Answers**

# %% [markdown]
# 1. Principal Component Analysis (PCA)
# 2. Data Scaling/Normalization
# 3. Missing Values

# %% [markdown]
#  Let's explore some of these in the context of preprocessing unsupervised data:

# %% [markdown]
# ### **Data Cleaning**

# %% [markdown]
# ![datacleaning.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The first preprocessing step is data cleaning. It involves handling missing values, removing outliers, and addressing any inconsistencies or errors in the data. 👩‍💻
#
# **Missing Values:** Missing data can be problematic for analysis and modeling. One common approach is to impute missing values by replacing them with estimated values based on the available data. This can be done using techniques like mean imputation (replacing missing values with the mean of the feature) or regression imputation (predicting missing values based on other variables). Alternatively, if the missing values are limited in number, you may choose to remove the corresponding rows or columns from the dataset. 📊
#
# **Outlier Removal:** Outliers are extreme values that deviate significantly from the normal pattern of the data. They can negatively impact the analysis and modeling process. Outliers can be identified using statistical methods such as the Z-score or the interquartile range (IQR). Once identified, outliers can be removed or transformed to minimize their influence on the analysis. 📉
#
# Data Consistency: Inconsistencies or errors in the data, such as incorrect or inconsistent formatting, inconsistent encoding, or duplicate records, should be addressed. These issues can be resolved by performing data validation checks, standardizing the data format, and resolving any inconsistencies or duplicates. 🔍
#
# Data cleaning is a crucial step in preparing the data for further analysis and modeling. By handling missing values, removing outliers, and ensuring data consistency, you can improve the quality and reliability of your data, leading to more accurate and meaningful results. 🧹

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.impute import SimpleImputer
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load data using Scikit-Learn (Wine dataset)
wine = load_wine()
X, y = wine.data, wine.target

# Step 2: Convert data to a pandas DataFrame
df = pd.DataFrame(data=X, columns=wine.feature_names)

# Step 3: Create missing values in the DataFrame
# Here, we set 10% of the data in each feature to NaN (missing value)
np.random.seed(42)
mask = np.random.rand(*df.shape) < 0.1
df_with_missing = df.copy()
df_with_missing[mask] = np.nan

# Step 4: Preprocess missing values using mean imputation
imputer = SimpleImputer(strategy='mean')
df_imputed = pd.DataFrame(imputer.fit_transform(df_with_missing), columns=df.columns)

# Step 5: Outlier removal using Z-score method
z_scores = np.abs(stats.zscore(df_imputed))
outlier_mask = (z_scores < 3).all(axis=1)  # Keep samples with all features within 3 standard deviations
df_no_outliers = df_imputed[outlier_mask]

# Step 6: Visualization of different techniques
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Original DataFrame with missing values
sns.heatmap(df_with_missing.isnull(), cbar=False, cmap='viridis', ax=axes[0, 0])
axes[0, 0].set_title("Original DataFrame\nwith Missing Values")

# DataFrame after Mean Imputation
sns.heatmap(df_imputed.isnull(), cbar=False, cmap='viridis', ax=axes[0, 1])
axes[0, 1].set_title("DataFrame after\nMean Imputation")

# Original DataFrame (without outliers)
sns.boxplot(data=df, ax=axes[1, 0])
axes[1, 0].set_title("Original DataFrame\n(Box Plot)")

# DataFrame after Outlier Removal
sns.boxplot(data=df_no_outliers, ax=axes[1, 1])
axes[1, 1].set_title("DataFrame after\nOutlier Removal")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Explanation:**
#
# Original DataFrame with Missing Values (Heatmap):
#
# 1. In the first heatmap, we visualize the original DataFrame with missing values. NaN values are represented in dark colors (purple in this case).
#
#  * Each row corresponds to a sample (wine) from the dataset, and each column represents a feature (chemical analysis) of the wine.
#  * The dark cells indicate the missing values, where we deliberately introduced NaNs in approximately 10% of the data.
#  * This visualization helps us identify the locations of missing values in the dataset, which is essential for preprocessing.
#
# 2. DataFrame after Mean Imputation (Heatmap):
#
#  * In the second heatmap, we visualize the DataFrame after applying mean imputation to handle the missing values.
#  * After mean imputation, the NaN values are replaced with the mean value of their respective features.
#  * As a result, all the dark cells (NaN values) in the original heatmap are now filled with mean values, indicated by different colors.
#  * This visualization shows how mean imputation replaces missing values, ensuring a complete dataset for unsupervised learning.
#
# 3. Original DataFrame (Box Plot):
#
#  * In the first box plot, we visualize the original DataFrame without any preprocessing, including missing values and outliers.
#  * Each box plot represents the distribution of a feature across all wine samples.
#  * Outliers are represented as individual points outside the whiskers of the box plot.
#  * The box shows the interquartile range (IQR), and the whiskers extend to the data within 1.5 times the IQR.
#  * This visualization helps us identify outliers in each feature of the dataset.
#
# 4. DataFrame after Outlier Removal (Box Plot):
#
#  * In the second box plot, we visualize the DataFrame after applying the Z-score method for outlier removal.
#  * The Z-score method identifies outliers based on how many standard deviations they deviate from the mean.
#  * Samples with any feature outside 3 standard deviations are considered outliers and removed from the dataset.
#  * As a result, the box plots show a reduced number of outliers compared to the original box plots.
#  * This visualization demonstrates how the Z-score method removes outliers and improves the data quality for unsupervised learning.

# %% [markdown]
# ### **Data Scaling/ Normalization**

# %% [markdown]
# Data scaling/normalization involves transforming the numerical features of the dataset to a common scale. This step ensures that all features have a similar range, preventing any one feature from dominating the analysis due to its larger scale. Scaling is particularly important for algorithms that rely on distance calculations or optimization techniques. ✨📊
#
# Two common methods of scaling/normalization are:
#
# Min-Max Scaling: This method rescales the data to a specific range, typically between 0 and 1. It involves subtracting the minimum value of the feature and dividing it by the difference between the maximum and minimum values. 📉🔢
#
# Standardization: This method transforms the data to have a mean of 0 and a standard deviation of 1. It involves subtracting the mean of the feature and dividing it by the standard deviation. 📏🔢
#
# The choice between these methods depends on the specific characteristics of the data and the requirements of the problem. 🤔💡
#
# It's important to note that the preprocessing steps may vary depending on the specific analysis or modeling techniques being employed, and it's always recommended to tailor the preprocessing steps to the specific needs of the data and problem at hand. 🛠️🔎

# %% [markdown]
# ### **Min-Max Scaling**

# %% [markdown]
# Min-max scaling, also known as normalization, is a common data preprocessing technique used to transform numerical data to a specific range, typically between 0 and 1. 📊🔢

# %% [markdown]
# **The process involves the following steps:**
#
# 1. Identify the minimum and maximum values of the feature you want to scale. 📈📉
#
# 2. Apply the min-max scaling formula to each value in the feature:
#
#  min_max_scaled_value = (value - min_value) / (max_value - min_value)
#
# 3. This formula subtracts the minimum value from each data point and divides it by the range (the difference between the maximum and minimum values). It scales the values proportionally within the range of 0 to 1. 🔢🔍
#
# 4. Repeat the above steps for all the features you want to scale. 🔄

# %% [markdown]
# **Min-max scaling has several benefits:**
#
# 1. It brings different features onto a comparable scale, ensuring that no single
# feature dominates the analysis or modeling process due to its larger value range. ⚖️🔀
#
# 2. It preserves the original distribution and relationships between the data points while transforming them to a common range. 📊🔄
#
# 3. It can help improve the performance of certain machine learning algorithms, especially those that rely on distance calculations or optimization techniques. 🤖🔬
#
# Using min-max scaling can be beneficial in various scenarios, but it's important to consider the specific characteristics of the data and the requirements of the problem at hand. 🤔💡

# %% [markdown]
# **Let's use an example to explain min-max scaling.**
#
# Suppose we have a dataset of students' exam scores with two features: the number of hours studied (ranging from 0 to 10 hours) and the score achieved (ranging from 0 to 100). Here's a sample of the data:

# %% [markdown]
# ![tab1.png](data:image/png;base64,...)

# %% [markdown]
# In min-max scaling, we transform the data to a specific range, typically between 0 and 1. This is done by subtracting the minimum value from each feature and dividing it by the difference between the maximum and minimum values.
#
# To min-max scale the "Hours Studied" feature:
#
# Find the minimum and maximum values:
#
# * min_value = 0
#
# * max_value = 10
#
# Apply the min-max scaling formula to each value:
#
# * min_max_scaled_value = (value - min_value) / (max_value - min_value)
#
# For example, for the first student who studied for 2 hours:
#
# * min_max_scaled_hours = (2 - 0) / (10 - 0) = 0.2

# %% [markdown]
# Following the same process, we can calculate the min-max scaled values for all the "Hours Studied". The min-max scaled "Hours Studied" column would look like this:
#
#
# ![tab2.png](data:image/png;base64,...)

# %% [markdown]
# Next, let's min-max scale the "Score" feature:
#
# Find the minimum and maximum values:
# * min_value = 0
# * max_value = 100
#
# Apply the min-max scaling formula to each value:
#
# * min_max_scaled_value = (value - min_value) / (max_value - min_value)
#
# For example, for the first student who achieved a score of 50:
#
# * min_max_scaled_score = (50 - 0) / (100 - 0) = 0.5

# %% [markdown]
# Calculating the min-max scaled values for all the scores, the min-max scaled "Score" column would be as follows:
#
# ![tab3.png](data:image/png;base64,...)

# %% [markdown]
# After min-max scaling, both features, "Hours Studied" and "Score", are transformed to a common range between 0 and 1. This allows for fair comparisons and analysis, as they are now on a comparable scale.
#
# Min-max scaling is particularly useful when different features have significantly different ranges and when preserving the original distribution and relationships between features is important.
#
# Note: It's important to apply min-max scaling to the training data and use the same scaling parameters to transform the test or unseen data to ensure consistency in the scaling process.

# %%
# !pip install plotly

# %%
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load data using Scikit-Learn (Wine dataset)
wine = load_wine()
X, y = wine.data, wine.target

# Step 2: Convert data to a pandas DataFrame
df = pd.DataFrame(data=X, columns=wine.feature_names)

# Step 3: Create Min-Max scaler
min_max_scaler = MinMaxScaler()

# Step 4: Apply Min-Max scaling to the DataFrame
df_min_max_scaled = pd.DataFrame(min_max_scaler.fit_transform(df), columns=df.columns)

# Step 5: Visualization of the dataset after Min-Max scaling using shaded KDE plot
plt.figure(figsize=(12, 6))

# Original DataFrame KDE shaded plot
for i, col in enumerate(df.columns):
    sns.kdeplot(df[col], label=f"Feature {i+1} (Original)", shade=True, linewidth=2)

plt.xlabel('Feature Values')
plt.ylabel('Density')
plt.title('Original Dataset - KDE Shaded Plot')
plt.legend()

# Min-Max Scaled DataFrame KDE shaded plot
plt.figure(figsize=(12, 6))
for i, col in enumerate(df_min_max_scaled.columns):
    sns.kdeplot(df_min_max_scaled[col], label=f"Feature {i+1} (Min-Max Scaled)", shade=True, linewidth=2)

plt.xlabel('Scaled Feature Values (Min-Max Scaled)')
plt.ylabel('Density')
plt.title('Min-Max Scaled Dataset - KDE Shaded Plot')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-3-ab59d3821f2a>:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], label=f"Feature {i+1} (Original)", shade=True, linewidth=2)
# <ipython-input-3-ab59d3821f2a>:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], label=f"Feature {i+1} (Original)", shade=True, linewidth=2)
# <ipython-input-3-ab59d3821f2a>:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], label=f"Feature {i+1} (Original)", shade=True, linewidth=2)
# <ipython-input-3-ab59d3821f2a>:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...

# %% [markdown]
# ### **Standardization**

# %% [markdown]
# Standardization, also known as z-score normalization, is a preprocessing technique used to transform the features of a dataset to have a mean of 0 and a standard deviation of 1. It is a common practice in machine learning and data analysis to bring variables onto a common scale for fair comparison and to avoid certain features dominating the analysis due to their larger scales.

# %% [markdown]
# The process of standardization involves the following steps:
#
# 1. Calculate the mean (average) of the feature.
#
# 2. Calculate the standard deviation, which measures the spread or dispersion of the feature's values.
#
# 3. For each data point in the feature, subtract the mean and divide by the standard deviation to obtain the standardized value.
#
# By standardizing the features, the data is transformed to have a standard distribution, with values centered around 0 and a spread determined by the standard deviation. This allows for easier interpretation and comparison of the data, and it can be beneficial for certain machine learning algorithms that assume standardized input.
#
# Standardization is particularly useful when features have different scales or units of measurement, as it brings them to a comparable level. It also helps in handling outliers by reducing their impact on the data analysis.

# %% [markdown]
# Let's dive into standardization with an example.
#
# Suppose you have a dataset containing information about students' test scores and their ages. Here's a sample of the data:
#
# ![tab4.png](data:image/png;base64,...)

# %% [markdown]
# In standardization, we transform the data in such a way that it has a mean of 0 and a standard deviation of 1. This is also referred to as z-score normalization.
#
# To standardize a feature, we follow these steps:
#
# 1. Calculate the mean of the feature.
#
# 2. Calculate the standard deviation of the feature.
#
# 3. Apply the formula to calculate the standardized values for each data point.

# %% [markdown]
# Let's standardize the Test Score feature:
#
# 1. Calculate the mean of the Test Score:
#
#    mean = (80 + 90 + 70 + 85 + 95) / 5 = 84
#
# 2. Calculate the standard deviation of the Test Score:
#
#    standard_deviation = sqrt(((80 - 84)^2 + (90 - 84)^2 + (70 - 84)^2 + (85 - 84)^2 + (95 - 84)^2) / 5) ≈ 8.37
#
# 3. Apply the formula to calculate the standardized values for each test score:
#
#    standardized_test_score = (value - mean) / standard_deviation
#
#    For example, for the first student with a test score of 80:
#
#    standardized_test_score = (80 - 84) / 8.37 ≈ -0.48

# %% [markdown]
# By performing the same calculation for all test scores in the dataset, we obtain the standardized Test Score column:
#
# ![tab5.png](data:image/png;base64,...)

# %% [markdown]
# It's important to note that standardization does not change the underlying distribution of the data, but rather re-scales it to a standardized range.

# %%
# !pip install plotly

# %%
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load data using Scikit-Learn (Wine dataset)
wine = load_wine()
X, y = wine.data, wine.target

# Step 2: Convert data to a pandas DataFrame
df = pd.DataFrame(data=X, columns=wine.feature_names)

# Step 3: Create StandardScaler
standard_scaler = StandardScaler()

# Step 4: Apply Standardization to the DataFrame
df_standardized = pd.DataFrame(standard_scaler.fit_transform(df), columns=df.columns)

# Step 5: Visualization of the dataset after Standardization using shaded KDE plot
plt.figure(figsize=(12, 6))

# Original DataFrame KDE shaded plot
for i, col in enumerate(df.columns):
    sns.kdeplot(df[col], label=f"Feature {i+1} (Original)", shade=True, linewidth=2)

plt.xlabel('Feature Values')
plt.ylabel('Density')
plt.title('Original Dataset - KDE Shaded Plot')
plt.legend()

# Standardized DataFrame KDE shaded plot
plt.figure(figsize=(12, 6))
for i, col in enumerate(df_standardized.columns):
    sns.kdeplot(df_standardized[col], label=f"Feature {i+1} (Standardized)", shade=True, linewidth=2)

plt.xlabel('Standardized Feature Values')
plt.ylabel('Density')
plt.title('Standardized Dataset - KDE Shaded Plot')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-edd462b850bd>:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], label=f"Feature {i+1} (Original)", shade=True, linewidth=2)
# <ipython-input-5-edd462b850bd>:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], label=f"Feature {i+1} (Original)", shade=True, linewidth=2)
# <ipython-input-5-edd462b850bd>:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], label=f"Feature {i+1} (Original)", shade=True, linewidth=2)
# <ipython-input-5-edd462b850bd>:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...

# %% [markdown]
# ### **Activity 2: True or False**
# 1) Min-max scaling transforms numerical data to a specific range, typically between -1 and 1.
#
# a. True
#
# b. False
#
# 2)Data cleaning involves handling missing values, but it does not address outliers or data consistency issues.
#
# a. True
#
# b. False
#
# 3)Min-max scaling helps in preserving the original distribution and relationships between the data points while transforming them to a common range.
#
# a. True
#
# b. False
#
# 4)Outliers can positively impact the analysis and modeling process, as they provide valuable insights into extreme cases within the data.
#
# a. True
#
# b. False

# %% [markdown]
# #### **Activity 2 Answers**
# 1. False
# 2. False
# 3. True
# 4. False

# %% [markdown]
# ## **Implementing Unsupervised Algorithms**

# %% [markdown]
# Unsupervised learning 🕵️‍♀️ is a powerful technique used to extract insights  🔎 and patterns from unlabeled data. In this session, we will explore how to use Scikit-Learn, a popular machine learning library, along with other Python libraries, 📈 to implement various unsupervised algorithms. We will cover data preprocessing, algorithm selection, model fitting, and result analysis 💻.
#
# Let's dive in!

# %% [markdown]
# Step 1: Import the necessary libraries
#
# In this step, we import the required libraries, including Scikit-Learn, NumPy, and Matplotlib. We will also enable inline plotting for Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Step 2: Load and preprocess the data
#
# In this step, we load the dataset and preprocess it as needed. For simplicity, we'll use the Iris dataset and perform feature scaling.

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# Load the Iris dataset
data = load_iris()
X = data.data

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Step 3: Choose an unsupervised algorithm
#
# In this step, we select the unsupervised algorithm we want to use. Here, we'll choose the K-Means clustering algorithm as an example.

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# Step 4: Initialize and fit the model
# In this step, we create an instance of the chosen algorithm and fit it to the preprocessed data. Adjust the hyperparameters as needed.

# %%
# Initialize and fit the K-Means model
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %% [markdown]
# Step 5: Analyze the results
#
# In this step, we analyze the results obtained from the trained model. For K-Means, we'll plot the clusters.

# %%
# Get the cluster assignments
labels = kmeans.labels_

# Visualize the clusters
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# We visualize the clusters by creating a scatter plot using Matplotlib. We plot the data points from the original dataset (X) using the first two features (X[:, 0] and X[:, 1]) as the x and y coordinates. The color of each data point is determined by its cluster assignment (labels).
#
# The resulting scatter plot shows the clusters identified by the K-Means algorithm, where each data point is color-coded according to its assigned cluster.

# %% [markdown]
# ## **Evaluating Clustering and Dimensionality Reduction Models**

# %% [markdown]
# When evaluating clustering and dimensionality reduction models, several commonly used metrics and techniques can provide insights into the quality and performance of the models. Three such evaluation methods are the silhouette score, the elbow method, and reconstruction error.
#
#  Let's explore each of these techniques: 😊📊

# %% [markdown]
# ### **Silhouette Score**

# %% [markdown]
# The silhouette score is a metric used to evaluate the quality of clustering results. It measures how well each sample in a cluster fits with its own cluster compared to other clusters. A higher silhouette score indicates better-defined and well-separated clusters.
#
# The silhouette score ranges from -1 to 1:
#
# 1. A score close to 1 indicates that the sample is well-matched to its own
#   cluster and poorly matched to neighboring clusters.
#
# 2. A score close to 0 indicates that the sample is on or very close to the
#    decision boundary between two neighboring clusters.
#
# 3. A score close to -1 indicates that the sample is likely assigned to the
#    wrong cluster.

# %% [markdown]
# Here's an example of calculating the silhouette score using scikit-learn:

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Generate synthetic data with 2 clusters
X, y = make_blobs(n_samples=100, n_features=2, centers=2, random_state=42)

# Apply clustering algorithm
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X)

# Obtain cluster assignments
labels = kmeans.labels_

# Calculate the silhouette score
silhouette_avg = silhouette_score(X, labels)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.8329367162955609

# %% [markdown]
# In this example, we first generate synthetic data using the make_blobs function from scikit-learn, creating two clusters. We then apply the K-Means clustering algorithm to cluster the data points. The labels variable contains the cluster assignments obtained from K-Means.
#
# Next, we calculate the silhouette score using the silhouette_score function. The function takes the feature matrix X and the cluster labels labels as inputs. It computes the average silhouette score across all samples, representing the overall quality of the clustering.
#
# Finally, we print the silhouette score to assess the clustering results. A higher score closer to 1 indicates better-defined clusters.

# %% [markdown]
# The silhouette score is a useful metric to compare different clustering algorithms, evaluate the number of clusters, and assess the quality of clustering results. However, it should be used in conjunction with other evaluation methods and domain knowledge for a comprehensive analysis of the clustering performance. ✨🔍

# %% [markdown]
# ### **Elbow Method**

# %% [markdown]
# The elbow method is a technique used to determine the optimal number of clusters in a clustering algorithm. It helps identify the "elbow" point on a plot of the within-cluster sum of squares (WCSS) or inertia against the number of clusters. The elbow point represents a balance between the model's ability to minimize within-cluster variance and avoid overfitting.
#
# The steps involved in the elbow method are as follows:
#
# 1. Apply a clustering algorithm (e.g., K-Means) to the dataset for a range of
#  different cluster numbers (k values).
#
# 2. For each k value, calculate the WCSS or inertia, which represents the sum of
#  squared distances between each data point and its centroid within the cluster.
#
# 3. Plot the WCSS or inertia values against the corresponding k values.
#
# 4. Analyze the resulting plot and identify the elbow point, where the rate of
#  improvement in WCSS or inertia decreases significantly. This point indicates a trade-off between the number of clusters and the overall model performance.

# %% [markdown]
# Here's an example of using the elbow method with the K-Means algorithm in scikit-learn:

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Generate synthetic data
X, _ = make_blobs(n_samples=100, n_features=2, centers=5, random_state=42)

# Define range of k values
k_values = range(1, 10)
inertias = []

# Apply K-Means for different k values
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

# Plot the elbow curve
plt.plot(k_values, inertias, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Within-Cluster Sum of Squares (WCSS)')
plt.title('Elbow Method')
plt.show()

# %% [markdown]
# In this example, we first generate synthetic data using the make_blobs function from scikit-learn. We then define a range of k values (number of clusters) to evaluate.
#
# Next, we iterate over the k values and apply the K-Means algorithm for each k value. We calculate and store the corresponding WCSS (inertia) using the inertia_ attribute of the K-Means model.
#
# Finally, we plot the elbow curve, showing the WCSS values against the number of clusters. The elbow point on the curve indicates the optimal number of clusters.

# %% [markdown]
# By observing the plot, you can identify the elbow point where the WCSS improvement begins to level off. This suggests the appropriate number of clusters to use for the dataset. However, it's important to note that the elbow method is subjective, and domain knowledge should be considered in conjunction with this technique to make informed decisions about the optimal number of clusters. 🔍⛰️💡

# %% [markdown]
# ### **Reconstruction Error**

# %% [markdown]
# Reconstruction error is a metric used to evaluate the quality of dimensionality reduction techniques, particularly those that involve data reconstruction. It measures the discrepancy or error between the original data and the reconstructed data after reducing the dimensions. 🔍🏗️📉
#
# The reconstruction error quantifies how well the reduced-dimensional representation captures the important information from the original data. A lower reconstruction error indicates a more accurate representation of the original data and implies that less information was lost during the dimensionality reduction process. 📊🔢🔍
#
# One common dimensionality reduction technique that uses reconstruction is Principal Component Analysis (PCA). PCA aims to find orthogonal directions (principal components) that capture the maximum variance in the data. The reconstruction process involves projecting the reduced-dimensional data back into the original high-dimensional space. 💡📉🔁
#
# To calculate the reconstruction error, you need to compare the original data with the reconstructed data and measure their similarity. Mean squared error (MSE) is often used as the reconstruction error metric.

# %% [markdown]
# Here's an example of calculating the reconstruction error using PCA in scikit-learn:

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.metrics import mean_squared_error

# Load the Iris dataset
data = load_iris()
X = data.data

# Apply PCA for dimensionality reduction
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X)

# Reconstruct the data
X_reconstructed = pca.inverse_transform(X_reduced)

# Calculate the reconstruction error (MSE)
reconstruction_error = mean_squared_error(X, X_reconstructed)
print("Reconstruction Error:", reconstruction_error)
# Out:
# Reconstruction Error: 0.025341073932398255

# %% [markdown]
# In this example, we load the Iris dataset using load_iris from scikit-learn. We then apply PCA to reduce the dimensionality of the data to two components.
#
# After dimensionality reduction, we reconstruct the data by applying the inverse transformation (inverse_transform) to the reduced data, obtaining X_reconstructed.
#
# Finally, we calculate the reconstruction error using the mean squared error (mean_squared_error) between the original data (X) and the reconstructed data (X_reconstructed).

# %% [markdown]
# A lower reconstruction error indicates a more accurate ✅ representation of the original data. The reconstruction error can be used to assess the quality of dimensionality reduction and compare different techniques or configurations. However, it is important to consider other factors such as the retained variance and the specific objectives of the dimensionality reduction task.💡

# %% [markdown]
# ### **Activity 3: Match the following**
#
# Section A:
#
# 1. What is the silhouette score used to evaluate?
#
# 2. Which metric measures the discrepancy between original data and reconstructed data in dimensionality reduction techniques?
#
# 3. What does the elbow point on the curve represent in the context of the elbow method?
#
# 4. Which clustering algorithm is commonly used in the elbow method to calculate the within-cluster sum of squares (WCSS) for different cluster numbers?
#
# Section B:
#
#
#   A. Reconstruction Error.
#
#   B. The silhouette score is used to evaluate the quality of clustering results.
#
#   C. K-Means.
#
#   D. The elbow point on the curve represents the optimal number of clusters.

# %% [markdown]
# #### **Activity 3 Answers:**
# 1 -> B
# 2 -> A
# 3 -> D
# 4 -> C

# %% [markdown]
# ## **Deploying unsupervised models in production**

# %% [markdown]
# Deploying unsupervised models in production involves making the models accessible 👌 and operational in a production environment, allowing them to generate predictions 💡 or perform tasks on new, 🔍 unseen data.
#
#  There are two common approaches for deploying unsupervised models: batch processing and real-time streaming. Let's explore each of these approaches:

# %% [markdown]
# ### **Batch Proccessing**

# %% [markdown]
# Batch processing is a technique where 🔢 data is collected and processed in groups or batches  rather than in real-time ⏲ or as it arrives. In this approach, data is accumulated over a period of time, and the processing is performed on the entire batch at once. Batch processing is commonly used when immediate results or real-time analysis are not necessary, and it offers several advantages such as ✅ efficient resource utilization and the ability to handle 💭 large volumes of data.

# %% [markdown]
# Here's a simplified example of batch processing:
#
# Let's say you have a dataset containing customer transaction records for an e-commerce platform. The goal is to perform customer segmentation using unsupervised clustering algorithms. Here's how batch processing can be applied:

# %% [markdown]
# 1. **Data Collection:** Accumulate the transaction data over a specific time
#  period, such as a day or a week.
#
# 2. **Data Preprocessing:** Perform any necessary data cleaning, normalization, or feature engineering steps on the collected data. This may involve removing missing values, scaling the features, or encoding categorical variables.
#
# 3. **Clustering Model Training:** Apply the unsupervised clustering algorithm, such as K-Means, to the preprocessed data. Train the model using the entire batch of data.
#
# 4. **Clustering Model Evaluation:** Assess the quality of the clustering results using appropriate evaluation metrics, such as silhouette score or within-cluster sum of squares (WCSS).
#
# 5. **Post-Processing and Analysis:** Analyze the clustering results to gain insights and understanding of customer segments. This may involve visualizing the clusters, computing cluster centroids, or extracting meaningful patterns from the data.
#
# 6. **Storage or Output:** Store the clustering results or use them for downstream tasks, such as targeted marketing campaigns, personalized recommendations, or customer behavior analysis.

# %% [markdown]
# In this example, the batch processing approach allows you to process a large volume of transaction data collected over a specific time period. The entire dataset is processed as a batch, and the clustering model is trained and applied to the complete dataset at once. This enables efficient resource utilization as the computations can be performed in bulk, and it eliminates the need for real-time or continuous data processing.
#
# Batch processing is commonly used in scenarios where real-time decision-making is not required, and it offers benefits such as the ability to process large volumes of data efficiently, simplified resource management, and the opportunity for offline analysis and optimization.
#
# ---

# %% [markdown]
# ### **Real-Time Streaming**

# %% [markdown]
# Real-time streaming involves processing and analyzing data as it arrives in a continuous, streaming fashion. This approach enables immediate insights, decision-making, and actions based on the incoming data. Real-time streaming is commonly used in scenarios where low latency and real-time analysis are crucial, such as fraud detection, IoT sensor data processing, or real-time monitoring.

# %% [markdown]
# Here's an example to illustrate real-time streaming:
#
# Let's say you are building a system to monitor social media sentiment in real-time. The goal is to analyze incoming tweets and determine whether they are positive, negative, or neutral. Here's how real-time streaming can be applied:

# %% [markdown]
# 1. **Data Ingestion:** Set up a data ingestion pipeline to collect and stream tweets in real-time from various sources. This can be done using technologies like Apache Kafka or RabbitMQ.
#
# 2. **Data Preprocessing**: As tweets arrive, apply necessary preprocessing steps to clean and transform the data. This may involve removing irrelevant information, tokenizing text, removing stop words, or applying sentiment analysis techniques.
#
# 3. **Real-time Sentiment Analysis:** Use a pre-trained sentiment analysis model or algorithm to classify the sentiment of each tweet. This can be achieved using machine learning techniques or rule-based approaches.
#
# 4. **Post-processing and Analysis:** Perform additional post-processing on the sentiment analysis results, such as aggregating sentiment scores over a specific time window or identifying trends in sentiment.
#
# 5. **Actions and Notifications:** Based on the real-time sentiment analysis results, trigger immediate actions or notifications. For example, if a significant increase in negative sentiment is detected, send an alert or notify a team for further investigation.
#
# 6. **Storage or Output:** Store the streaming data, sentiment analysis results, or any derived insights for further analysis or reporting. This can involve using databases or data lakes to capture and store the streaming data.

# %% [markdown]
# In this example, real-time streaming allows you to continuously process and analyze incoming tweets as they arrive. The system performs sentiment analysis in real-time, enabling immediate insights into the sentiment trends on social media.

# %% [markdown]
# Real-time streaming is typically implemented using specialized streaming frameworks or platforms such as Apache Kafka, Apache Flink, or Apache Spark. These technologies provide capabilities for data ingestion, distributed processing, and handling high volumes of streaming data efficiently.
#
# It's important to consider the scalability, fault-tolerance, and processing latency requirements when building real-time streaming systems. Additionally, monitoring and managing the streaming infrastructure and ensuring data consistency and integrity are crucial aspects of successful real-time streaming deployments.
#
# ---

# %% [markdown]
# ## **Best practices for working with unsupervised data**

# %% [markdown]
# When working with unsupervised data, there are several best practices to consider. Here are three important ones: outlier detection, data scaling, and handling imbalanced datasets.

# %% [markdown]
# ### **Outlier Detection**

# %% [markdown]
# ![outlier.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Outliers are data points that deviate significantly from the majority of the data. They can have a significant impact on the performance and results of unsupervised algorithms. It's important to identify and handle outliers appropriately. Some best practices for outlier detection include:
#
# 1. Visual exploration: Plotting the data and visually inspecting for any data points that appear significantly different from the majority.
#
# 2. Statistical methods: Utilizing statistical techniques such as z-scores, percentiles, or box plots to detect outliers based on the distribution of the data.
#
# 3. Unsupervised outlier detection algorithms: Applying algorithms like DBSCAN (Density-Based Spatial Clustering of Applications with Noise) or Isolation Forest to automatically identify outliers in the data.

# %% [markdown]
# Let's consider an example where we have a dataset of random numbers, and we want to detect and visualize outliers using the z-score method:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Generate random data
np.random.seed(42)
data = np.random.normal(0, 1, 1000)

# Calculate z-scores
z_scores = zscore(data)

# Set a threshold for outlier detection
threshold = 3

# Identify outliers
outliers = np.abs(z_scores) > threshold

# Visualize the data and outliers
plt.figure(figsize=(10, 6))
plt.scatter(range(len(data)), data, c=outliers, cmap='coolwarm')
plt.xlabel('Index')
plt.ylabel('Data')
plt.title('Outlier Detection')
plt.colorbar(label='Outlier')
plt.show()

# %% [markdown]
# In this code, we generate a dataset of 1000 random numbers using np.random.normal. We then calculate the z-scores of the data using the zscore function from the scipy.stats module.
#
# Next, we set a threshold for outlier detection. Typically, a z-score above a certain threshold (e.g., 3) is considered an outlier.
#
# We identify the outliers by comparing the absolute values of the z-scores to the threshold. If the absolute z-score exceeds the threshold, the corresponding data point is marked as an outlier.
#
# Finally, we visualize the data using a scatter plot, where outliers are colored differently using the c parameter of the scatter function. The color bar on the side represents whether a point is an outlier or not.
#
# This code provides a basic example of outlier detection using the z-score method and visualizing the outliers in the dataset. You can explore other outlier detection techniques and adjust the threshold or visualization settings based on your specific requirements and dataset characteristics.

# %% [markdown]
# ### **Data Scaling**

# %% [markdown]
# ![scalee.png](data:image/png;base64,...)

# %% [markdown]
# Unsupervised algorithms are sensitive to the scale and magnitude of the features. Data scaling is important to ensure that all features have a similar range or distribution. Some best practices for data scaling that we have already discussed before include:
#
# 1. Standardization: Scaling the data to have zero mean and unit variance using techniques like StandardScaler from scikit-learn.
#
# 2. Min-Max scaling: Scaling the data to a specific range, typically between 0 and 1, using techniques like MinMaxScaler from scikit-learn.
#
# 3. Robust scaling: Scaling the data using robust statistics that are less affected by outliers, such as the RobustScaler from scikit-learn.
#
# Choosing the appropriate scaling technique depends on the characteristics of the data and the requirements of the algorithm being used.

# %% [markdown]
# **Standardization**  is a common technique used to scale features by subtracting the mean and dividing by the standard deviation. This process transforms the data to have zero mean and unit variance.
#
#  Here's an example of how to use StandardScaler for standardization in Python:

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# Create a sample dataset
data = np.array([[1.2], [2.4], [3.6], [4.8]])

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data
scaled_data = scaler.fit_transform(data)

# Print the original and scaled data
print("Original Data:")
print(data)
print("\nScaled Data:")
print(scaled_data)
# Out:
# Original Data:
# [[1.2]
#  [2.4]
#  [3.6]
#  [4.8]]
#
# Scaled Data:
# [[-1.34164079]
#  [-0.4472136 ]
#  [ 0.4472136 ]
#  [ 1.34164079]]

# %% [markdown]
# In this example, we have a sample dataset data with four values. We import the StandardScaler from scikit-learn.
#
# Next, we initialize the StandardScaler by creating an instance of the StandardScaler class.
#
# We then fit the scaler to the data and transform it using the fit_transform method. This computes the mean and standard deviation from the data and applies the standardization transformation.
#
# Finally, we print the original data and the scaled data to observe the effect of standardization. The scaled data will have a mean of zero and a standard deviation of one.
#
# ---

# %% [markdown]
# **Min-Max Scaling** also known as normalization, is a technique used to scale features to a specific range, typically between 0 and 1. It transforms the data by subtracting the minimum value and dividing by the range.
#
# Here's an example of how to use the MinMaxScaler for min-max scaling in Python:

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Create a sample dataset
data = np.array([[1.2], [2.4], [3.6], [4.8]])

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the data
scaled_data = scaler.fit_transform(data)

# Print the original and scaled data
print("Original Data:")
print(data)
print("\nScaled Data:")
print(scaled_data)
# Out:
# Original Data:
# [[1.2]
#  [2.4]
#  [3.6]
#  [4.8]]
#
# Scaled Data:
# [[0.        ]
#  [0.33333333]
#  [0.66666667]
#  [1.        ]]

# %% [markdown]
# In this example, we have a sample dataset data with four values. We import the MinMaxScaler from scikit-learn.
#
# Next, we initialize the MinMaxScaler by creating an instance of the MinMaxScaler class.
#
# We then fit the scaler to the data and transform it using the fit_transform method. This computes the minimum and maximum values from the data and applies the min-max scaling transformation.
#
# Finally, we print the original data and the scaled data to observe the effect of min-max scaling. The scaled data will have values between 0 and 1.
#
# ---

# %% [markdown]
# **RobustScaler** is a technique used for scaling features in the presence of outliers. It scales the features by subtracting the median and dividing by the interquartile range, making it robust to outliers.
#
# Here's an example of how to use the RobustScaler in Python:

# %%
import numpy as np
from sklearn.preprocessing import RobustScaler

# Create a sample dataset with outliers
data = np.array([[1.2], [2.4], [3.6], [4.8], [100]])


# Initialize the RobustScaler
scaler = RobustScaler()

# Fit and transform the data
scaled_data = scaler.fit_transform(data)

# Print the original and scaled data
print("Original Data:")
print(data)
print("\nScaled Data:")
print(scaled_data)
# Out:
# Original Data:
# [[  1.2]
#  [  2.4]
#  [  3.6]
#  [  4.8]
#  [100. ]]
#
# Scaled Data:
# [[-1.        ]
#  [-0.5       ]
#  [ 0.        ]
#  [ 0.5       ]
#  [40.16666667]]

# %% [markdown]
# In this example, we create a sample dataset data with five values, including an outlier value of 100. We then import the RobustScaler from scikit-learn.
#
# Next, we initialize the RobustScaler by creating an instance of the RobustScaler class. No parameters are required for this example.
#
# We then fit the scaler to the data and transform it using the fit_transform method. This computes the median and interquartile range from the data and applies the scaling transformation.
#
# Finally, we print the original data and the scaled data to observe the effect of the RobustScaler on the outlier. The scaled data will show how the outlier is brought closer to the range of the other values.
#
# ---

# %% [markdown]
# ### **Handling Imbalanced Datasets**

# %% [markdown]
# ![an_overview_on_imbalanced_dataset_in_ml_and_techniques_to_handling_it.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Handling imbalanced datasets is an 💡 important consideration in 🤖 unsupervised learning, as it can impact the performance and ✅ accuracy of the algorithms. Imbalanced datasets refer to datasets where the distribution of classes or clusters is uneven, with one or more classes having significantly fewer samples than others. This can lead to biased results and 😵 difficulties in detecting the minority class or cluster.

# %% [markdown]
# Here are some techniques for handling imbalanced datasets:

# %% [markdown]
# **Oversampling:**
#
# 1. Oversampling involves increasing the number of instances in the minority class to balance the dataset.
#
# 2. This can be done by duplicating existing instances or generating synthetic samples using techniques like SMOTE (Synthetic Minority Over-sampling Technique).
#
# 3. Oversampling helps the algorithm to learn from the minority class more effectively.

# %% [markdown]
# ![0_FeIp1t4uEcW5LmSM.png](data:image/png;base64,...)

# %% [markdown]
# **Undersampling:**
#
# 1. Undersampling involves reducing the number of instances in the majority class to balance the dataset.
#
# 2. Randomly or strategically removing instances from the majority class can be used to achieve a balanced distribution.
#
# 3. Undersampling reduces the dominance of the majority class and ensures the algorithm is exposed to the minority class adequately.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# Step 1: Generate imbalanced dataset
X, y = make_classification(n_classes=2, class_sep=2, weights=[0.1, 0.9], n_informative=3, n_redundant=1,
                           flip_y=0, n_features=5, n_clusters_per_class=1, n_samples=1000, random_state=42)

# Function to plot scatter plot
def plot_scatter(X, y, title):
    plt.figure(figsize=(8, 6))
    plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], label='Class 0', alpha=0.5)
    plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], label='Class 1', alpha=0.5)
    plt.title(title)
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.legend()
    plt.show()

# Function to print sampling output
def print_sampling_output(X_resampled, y_resampled, technique):
    print(f"Sampling Technique: {technique}")
    print(f"Original Class Distribution: {dict(zip(*np.unique(y, return_counts=True)))}")
    print(f"Resampled Class Distribution: {dict(zip(*np.unique(y_resampled, return_counts=True)))}")
    print("=" * 40)

# Step 2: Plot original dataset using scatter plot
plot_scatter(X, y, 'Original Dataset - Scatter Plot')

# Step 3: Perform Random Oversampling
ros = RandomOverSampler(random_state=42)
X_ros, y_ros = ros.fit_resample(X, y)
plot_scatter(X_ros, y_ros, 'Random Oversampling - Scatter Plot')
print_sampling_output(X_ros, y_ros, 'Random Oversampling')

# Step 4: Perform Random Undersampling
rus = RandomUnderSampler(random_state=42)
X_rus, y_rus = rus.fit_resample(X, y)
plot_scatter(X_rus, y_rus, 'Random Undersampling - Scatter Plot')
print_sampling_output(X_rus, y_rus, 'Random Undersampling')

# Step 5: Perform SMOTE
smote = SMOTE(random_state=42)
X_smote, y_smote = smote.fit_resample(X, y)
plot_scatter(X_smote, y_smote, 'SMOTE - Scatter Plot')
print_sampling_output(X_smote, y_smote, 'SMOTE')
# Out:
# Sampling Technique: Random Oversampling
# Original Class Distribution: {0: 100, 1: 900}
# Resampled Class Distribution: {0: 900, 1: 900}
# ...
# Sampling Technique: Random Undersampling
# Original Class Distribution: {0: 100, 1: 900}
# Resampled Class Distribution: {0: 100, 1: 100}
# ...
# Sampling Technique: SMOTE
# Original Class Distribution: {0: 100, 1: 900}
# Resampled Class Distribution: {0: 900, 1: 900}
# ...

# %% [markdown]
# **Ensemble Methods:**
#
# 1. Ensemble methods combine multiple unsupervised learning models or techniques to handle imbalanced datasets effectively.
#
# 2. By combining the results of multiple models, ensemble methods can improve the overall performance and address class imbalance.
#
# 3. Examples of ensemble methods for unsupervised learning include clustering ensembles and anomaly detection ensembles.

# %% [markdown]
# **Anomaly Detection:**
#
# 1. Anomaly detection approaches can be used to treat the imbalanced class as an anomaly.
#
# 2. Techniques like One-Class SVM (Support Vector Machine) or Local Outlier Factor can identify instances that deviate significantly from the majority class.
#
# 3. Anomaly detection can help identify and handle the minority class effectively.

# %% [markdown]
# **Evaluation Metrics:**
#
# 1. When evaluating the performance of unsupervised algorithms on imbalanced datasets, it is crucial to choose appropriate evaluation metrics.
#
# 2. Accuracy alone may be misleading due to the imbalanced nature of the dataset.
#
# 3. Metrics like precision, recall, F1-score, or area under the ROC curve (AUC-ROC) can provide a more comprehensive assessment of model performance.

# %% [markdown]
# Here's a simple example to illustrate the handling of an imbalanced dataset using oversampling with the SMOTE technique:

# %%
from imblearn.over_sampling import SMOTE
from sklearn.datasets import make_classification

# Generate an imbalanced dataset
X, y = make_classification(n_samples=1000, n_features=10, weights=[0.95, 0.05], random_state=42)

# Apply SMOTE oversampling
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Check the class distribution after oversampling
unique, counts = np.unique(y_resampled, return_counts=True)
class_distribution = dict(zip(unique, counts))
print("Class distribution after oversampling:", class_distribution)
# Out:
# Class distribution after oversampling: {0: 947, 1: 947}

# %% [markdown]
# In this example, we generate an imbalanced dataset using scikit-learn's make_classification function. We set the weights to [0.95, 0.05] to create a highly imbalanced dataset with a minority class representing only 5% of the samples.
#
# We then use the SMOTE oversampling technique from the imblearn library to balance the dataset. The fit_resample method applies SMOTE oversampling to generate synthetic samples for the minority class.
#
# Finally, we check the class distribution after oversampling to ensure that the minority class has been adequately represented.
#
# ---

# %% [markdown]
# ### **Activity 4: Guess the word**
#
# 1. I am a technique used to handle imbalanced datasets by increasing the number of instances in the minority class. My goal is to balance the dataset and help algorithms learn from the minority class more effectively.
#
# Who am I?
#
# 2. I am a group of methods that combine multiple unsupervised learning models or techniques to address class imbalance in datasets. By leveraging the results of various models, I aim to improve overall performance and handle imbalanced data effectively.
#
# Who am I?
#
# 3. I am a set of metrics used to evaluate the performance of unsupervised algorithms on imbalanced datasets. I provide a more comprehensive assessment of model performance compared to accuracy alone, considering factors like precision, recall, F1-score, or AUC-ROC to account for the imbalanced nature of the data.
#
# Who am I?

# %% [markdown]
# #### **Activity 4 Answers**
# 1. Undersampling.
# 2. Anomaly Detection.
# 3. Evaluation Metrics.

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ###🧠 **What did you learn?** 🤔
#
#
#
# 1. Preprocessing unsupervised data involves techniques like normalization, standardization, and handling missing values, which are essential to prepare the data for analysis.
# 2. Various unsupervised algorithms can be implemented using Python libraries, such as Scikit-Learn, for clustering and dimensionality reduction tasks.
# 3.Evaluating unsupervised models requires specific metrics, including silhouette score, elbow method, and reconstruction error, to assess their performance and determine the optimal number of clusters or components.
# 4. Deploying unsupervised models in p4. roduction can be achieved through batch processing or real-time streaming, depending on the application requirements.
# 5. Working with unsupervised data demands best practices such as outlier detection, appropriate data scaling, and handling imbalanced datasets for effective and meaningful analysis.

# %% [markdown]
# ###**Best Practices/Tips**
#
# 1. Data preprocessing: Properly preprocess unsupervised data by applying normalization or standardization to bring features to a common scale and handling missing values with appropriate techniques such as imputation or removal.
# 2. Algorithm selection: Choose the most suitable unsupervised algorithms, like k-means for clustering or PCA for dimensionality reduction, based on the nature of the data and the specific problem you aim to solve.
# 3. Evaluation metrics: Use appropriate evaluation metrics, such as silhouette score to measure the quality of clustering results, elbow method to determine the optimal number of clusters, and reconstruction error for dimensionality reduction performance assessment.
# 4. Model deployment: Depending on the application requirements, deploy unsupervised models in production through batch processing for periodic analysis or real-time streaming for immediate and continuous insights.
# 5. Outlier detection: Address outliers in the data effectively, as they can significantly impact the results of unsupervised models. Consider using techniques like Z-score or isolation forests to identify and handle outliers appropriately.
# 6. Data scaling: Be mindful of the sensitivity of some unsupervised algorithms to data scaling. Scale the features appropriately to avoid biases and inaccurate results.
# 7. Imbalanced datasets: If dealing with imbalanced data, consider using oversampling, undersampling, or synthetic data generation techniques to balance the dataset and improve the performance of clustering or dimensionality reduction models.

# %% [markdown]
# ###**Shortcomings**
#
# 1. Ambiguous evaluation: Evaluating unsupervised models can be challenging due to the absence of ground truth labels. Metrics like silhouette score and reconstruction error provide insights, but their interpretation may still be subjective.
# 1. Computational complexity: Some unsupervised algorithms, particularly those for dimensionality reduction, can be computationally expensive, making them impractical for large datasets or real-time applications.
# 1. Interpretability: The results of unsupervised learning may lack interpretability, making it challenging to explain the underlying patterns or reasons for specific outcomes.
# 1. Scalability: Some unsupervised algorithms may not scale well with an increase in the size of the dataset, limiting their applicability to large-scale problems.
# 1. Dimensionality reduction loss: While dimensionality reduction techniques can aid in data visualization and processing, reducing dimensions may lead to the loss of important information, impacting the model's performance.
# 1. Outlier handling: The identification and handling of outliers require careful consideration, as the approach can significantly impact the final results of unsupervised analysis.
# 1. Algorithm assumptions: Certain unsupervised algorithms make specific assumptions about the data distribution, which may not hold true for all datasets. It's essential to be aware of these assumptions and their potential impact on the analysis.

# %% [markdown]
# #**🧠Enhance Your Knowledge🧠**

# %% [markdown]
# ###🤖🌲**Mnemonic**🕵️‍♂️🦉
#
# Mnemonics are texts or devices that helps you to remember a concept. Here's a mnemonic to help you remember Indexing and Slicing

# %% [markdown]
# In the city of FinTechopolis, there was a well-established bank called FinSafe Bank, known for its secure and reliable services. However, like any other financial institution, FinSafe Bank faced the constant threat of fraudulent activities. To safeguard its customers and maintain trust, the bank sought the expertise of two talented data scientists, Lily and James.
#
# Lily and James were tasked with developing a robust fraud detection system using unsupervised learning techniques. The goal was to identify suspicious transactions and detect potential fraud in real-time, ensuring the security of the bank's customers and assets.
#
# The first challenge was data preprocessing. Lily and James collected historical transaction data, which contained various features such as transaction amount, location, and time. They started by normalizing and standardizing the data to ensure consistent scaling across features. Additionally, they handled missing values using appropriate imputation methods to avoid biased results.
#
# With a clean and preprocessed dataset, Lily and James proceeded to implement unsupervised learning algorithms using Python libraries, including Scikit-Learn. They opted for an anomaly detection approach, where they aimed to identify transactions that deviated significantly from the norm. They utilized algorithms like Isolation Forest and Local Outlier Factor to detect unusual patterns indicative of potential fraud.
#
# To evaluate their models, they used metrics like the reconstruction error and the area under the Receiver Operating Characteristic (ROC) curve. The reconstruction error provided insights into the models' ability to reconstruct normal transactions accurately. Meanwhile, the ROC curve and the Area Under the Curve (AUC) allowed them to assess the overall performance of the models in distinguishing between normal and fraudulent transactions.
#
# As they fine-tuned the models, Lily and James were impressed with the results. The unsupervised learning models successfully identified fraudulent transactions with high accuracy, minimizing false positives and negatives. The system's ability to adapt to new patterns and continuously learn from incoming data made it an effective tool for real-time fraud detection.
#
# The final step was deploying the unsupervised models into production. Lily and James designed a real-time streaming system that continuously analyzed incoming transactions. Transactions flagged as potentially fraudulent were immediately routed for further investigation by FinSafe Bank's fraud prevention team.
#
# The success of Lily and James's fraud detection system earned them praise and recognition within the bank. Their work contributed to enhancing the security of FinSafe Bank's customers and fortifying the bank's reputation for trustworthiness.
#
# As the story of Lily and James spread, more financial institutions embraced the power of unsupervised learning for fraud detection. Their achievements inspired others to adopt best practices, such as outlier detection, data scaling, and real-time streaming, in their pursuit of combating financial fraud and ensuring a safer banking environment for everyone in FinTechopolis. And so, the journey of Lily and James continued, driven by their commitment to using data science and machine learning to create a safer and more secure financial landscape.

# %% [markdown]
# ###**📖Additional Reference Paper📖**

# %% [markdown]
# [Elbow Method vs Silhouette Score – Which is Better?](https://vitalflux.com/elbow-method-silhouette-score-which-better/)
#
# [Batch Processing vs. Stream Processing](https://rivery.io/blog/batch-vs-stream-processing-pros-and-cons-2/)
#
# [Unsupervised Learning: Algorithms and Examples](https://www.altexsoft.com/blog/unsupervised-machine-learning/)

# %% [markdown]
# #**Try it Yourself**

# %% [markdown]
# ### **Task 1: Working on assignment**

# %% [markdown]
# **Problem Statement:** *Customer Segmentation for Wholesale Business Optimization*
#
# You are a data scientist working for a wholesale company that supplies various products to different customers. Your task is to perform customer segmentation based on their annual spending behavior to gain insights and optimize business strategies.
#
# Dataset: "Wholesale Customers Data"
#
# Project Tasks:
#
# Data Exploration and Preprocessing:
#
# - Explore the "Wholesale Customers Data" to understand its structure, features, and data distribution.
# - Handle any missing values or outliers appropriately.
# - Perform feature scaling using standardization or normalization to bring all features to a similar scale.
#
# Unsupervised Algorithm Implementation:
#
# - Apply clustering algorithms like k-Means, hierarchical clustering, and DBSCAN to segment customers based on their spending behavior.
# - Determine the optimal number of clusters using techniques like the silhouette score or the elbow method.
#
# Customer Segmentation Insights:
#
# - Interpret the clustering results and identify distinct customer segments based on their spending patterns.
# - Analyze the characteristics of each segment, such as their preferred product categories and spending levels.
#
# Business Strategy Optimization:
#
# - Develop personalized marketing strategies and promotions for each customer segment to improve customer satisfaction and retention.
# - Identify high-value customer segments that contribute significantly to the company's revenue.
# - Optimize product assortment and inventory management based on customer preferences.
#
# Dimensionality Reduction and Visualization:
#
# - Use dimensionality reduction techniques like PCA or t-SNE to visualize the customer data in 2D or 3D space.
# - Present visualizations to gain deeper insights into the separability of customer segments.
#
#
# Performance Evaluation:
#
# Evaluate the performance of the clustering models using relevant metrics like the silhouette score.

# %% [markdown]
# dataset_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00292/Wholesale%20customers%20data.csv'

# %%
#Write your solution here

# %% [markdown]
# ### **Task 2: Community Engagement**
#
# Share the following on the AlmaBetter Community Platform within your Cohort group:
#
# i) Share the conclusions of your clustering methods.What strategy will you take for each customer segment to improve customer satisfaction and retention?
#
# ii) Propose a Mnemonic that differentiates between the dimensionality reduction techniques PCA and t-SNE .
